# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt             #visualisation
import seaborn as sns   #visualisation
# %matplotlib inline
sns.set(color_codes=True)

# %%
df = pd.read_csv("C:\\Users\\camer\\Desktop\\class stuff\\Semester 4\\ai lab\\DropSeq\\MCF7_Filtered_Normalised_3000_Data_train.txt", delimiter="\ ", engine='python', index_col=0)
print("Dataframe dimensions:", np.shape(df))
print("First column: ", df.iloc[:, 0])
# Out:
# Dataframe dimensions: (3000, 21626)
# First column:  "MALAT1"       1
# "MT-RNR2"      0
# "NEAT1"        0
# "H1-5"         0
# "TFF1"         4
#               ..
# "BRWD1-AS2"    0
# "RPS19BP1"     0
# "AUNIP"        0
# "TNK2"         0
# "SUDS3"        0
# Name: "AAAAACCTATCG_Normoxia", Length: 3000, dtype: int64

# %%
#do the same analysis
df.shape
# Out:
# (3000, 21626)

# %%
list(df.columns)
# Out:
# ['"AAAAACCTATCG_Normoxia"',
#  '"AAAACAACCCTA_Normoxia"',
#  '"AAAACACTCTCA_Normoxia"',
#  '"AAAACCAGGCAC_Normoxia"',
#  '"AAAACCTAGCTC_Normoxia"',
#  '"AAAACCTCCGGG_Normoxia"',
#  '"AAAACTCGTTGC_Normoxia"',
#  '"AAAAGAGCTCTC_Normoxia"',
#  '"AAAAGCTAGGCG_Normoxia"',
#  '"AAAATCGCATTT_Normoxia"',
#  '"AAAATCTACATA_Normoxia"',
#  '"AAAATGGCTCTC_Normoxia"',
#  '"AAAATGGGCCGG_Normoxia"',
#  '"AAACAAACTCAA_Normoxia"',
#  '"AAACAACGAATT_Normoxia"',
#  '"AAACAATGAGGT_Normoxia"',
#  '"AAACACGCCGCG_Normoxia"',
#  '"AAACAGCACGAC_Normoxia"',
#  '"AAACATACCCGT_Normoxia"',
#  '"AAACATGGATCC_Normoxia"',
#  '"AAACATTAGAAT_Normoxia"',
#  '"AAACCAACCGGT_Normoxia"',
#  '"AAACCAGCCTGG_Normoxia"',
#  '"AAACCAGGCTCT_Normoxia"',
#  '"AAACCAGGGCAC_Normoxia"',
#  '"AAACCCGATTTC_Normoxia"',
#  '"AAACCGACGTCG_Normoxia"',
#  '"AAACCGCTGCAT_Normoxia"',
#  '"AAACCGTCCCGC_Normoxia"',
#  '"AAACCGTTAGCC_Normoxia"',
#  '"AAACCGTTGGGG_Normoxia"',
#  '"AAACCGTTTCTT_Normoxia"',
#  '"AAACCTAGGAGA_Normoxia"',
#  '"AAACCTATTGTC_Normoxia"',
#  '"AAACCTCCACGA_Normoxia"',
#  '"AAACCTGAGGGA_Normoxia"',
#  '"AAACGCACGGAC_Normoxia"',
#  '"AAACGCTGGCTT_Normoxia"',
#  '"AAACGGAGTGAA_Normoxia"',
#  '"AAACGGCCCCCT_Normoxia"',
#  '"AAACGGCCTAGG_Normoxia"',
#  '"AAACGGCGGGTG_Normoxia"',
#  '"AAACTACCTAAC_Normoxia"',
#  '"AAACTCACCTGA_Normoxia"',
#  '"AAACTCCACAAG_Normoxia"',
#  '"AAACTCGGGGTG_Normoxia"',
#  '"AAACTGGGCCGT_Normoxia"',
#  '"AAACTGTCTCAA_Normoxia"',
#  '"AAACTTGCGGGT_Normoxia"',
#  '"AAACTTTCCCGT_Normoxia"',
#  '"AAAGAAGAGCCT_Normoxia"',
#  '"AAAGACAACTCC_Normoxia"',
#  '"AAAGACCGGGTG_Normoxia"',
#  '"AAAGACCGTCTG_Normoxia"',
#  '"AAAGCACTGTTA_Normoxia"',
#  '"AAAGCAGCGATC_Normoxia"',
#  '"AAAGCCCCATCT_Normoxia"',
#  '"AAAGCCTCTATG_Normoxia"',
#  '"AAAGCGTAACCG_Normoxia"',
#  '"AAAGCTAACATG_Normoxia"',
#  '"AAAGCTCAGACT_Normoxia"',
#  '"AAAGGAAGACCT_Normoxia"',
#  '"AAAGGACCAGAT_Normoxia"',
#  '"AAAGGACGCAAA_Normoxia"',
#  '"AAAGGCAAGGAA_Normoxia"',
#  '"AAAGGCAGGCCT_Normoxia"',
#  '"AAAGGCCGCATG_Normoxia"',
#  '"AAAGGCGAGGCG_Normoxia"',
#  '"AAAGGCGCGGTG_Normoxia"',
#  '"AAAGGGCCCCAT_Normoxia"',
#  '"AAAGGTATGGTG_Normoxia"',
#  '"AAAGTTAACTCG_Normoxia"',
#  '"AAATAGGTCCCG_Normoxia"',
#  '"AAATCACATGGG_Normoxia"',
#  '"AAATCACCGCCA_Normoxia"',
#  '"AAATCCAATTTA_Normoxia"',
#  '"AAATCCGACGCC_Normoxia"',
#  '"AAATCCTTCTTG_Normoxia"',
#  '"AAATCGCACTTC_Normoxia"',
#  '"AAATCGCAGTCA_Normoxia"',
#  '"AAATCGCGCTAT_Normoxia"',
#  '"AAATGAAAACCT_Normoxia"',
#  '"AAATGACCTTAG_Normoxia"',
#  '"AAATGACGCTTG_Normoxia"',
#  '"AAATGACTCAGC_Normoxia"',
#  '"AAATGCGTGGTG_Normoxia"',
#  '"AAATGCTGTCCG_Normoxia"',
#  '"AAATGGTCTGCG_Normoxia"',
#  '"AAATGTACAAGC_Normoxia"',
#  '"AAATGTCCCGCA_Normoxia"',
#  '"AAATTACGCCCC_Normoxia"',
#  '"AAATTCGTGCGG_Normoxia"',
#  '"AACAAAGCAACA_Normoxia"',
#  '"AACAAAGGGTTC_Normoxia"',
#  '"AACAAATCGTAT_Normoxia"',
#  '"AACAACCTACGA_Normoxia"',
#  '"AACAAGCCCTGG_Normoxia"',
#  '"AACAAGTCCAAT_Normoxia"',
#  '"AACAATAGCGTT_Normoxia"',
#  '"AACAATCCCACC_Normoxia"',
#  '"AACAATGGGGGG_Normoxia"',
#  '"AACAATTTAACC_Normoxia"',
#  '"AACACACACAGG_Normoxia"',
#  '"AACACCAGAATG_Normoxia"',
#  '"AACACCCAATAG_Normoxia"',
#  '"AACACCCCCCCG_Normoxia"',
#  '"AACACCGCGTGA_Normoxia"',
#  '"AACACGCAAAAT_Normoxia"',
#  '"AACACGCACGTT_Normoxia"',
#  '"AACACGCTTCGG_Normoxia"',
#  '"AACACTAACGTG_Normoxia"',
#  '"AACACTTGGTCG_Normoxia"',
#  '"AACACTTTCGCC_Normoxia"',
#  '"AACAGCCCCCGG_Normoxia"',
#  '"AACAGCCGTACA_Normoxia"',
#  '"AACAGCTCGACG_Normoxia"',
#  '"AACAGGATAGCT_Normoxia"',
#  '"AACAGGGATCGG_Normoxia"',
#  '"AACAGTCTAGTC_Normoxia"',
#  '"AACATACATGGC_Normoxia"',
#  '"AACATACTTCCG_Normoxia"',
#  '"AACATCCGCAAG_Normoxia"',
#  '"AACATCGAAGCC_Normoxia"',
#  '"AACATCGTCCAC_Normoxia"',
#  '"AACATCTTGCGC_Normoxia"',
#  '"AACATGTCGCAG_Normoxia"',
#  '"AACCAACTTTCT_Normoxia"',
#  '"AACCAATTCTGA_Normoxia"',
#  '"AACCACTACGAA_Normoxia"',
#  '"AACCAGCCATCG_Normoxia"',
#  '"AACCAGTGCATC_Normoxia"',
#  '"AACCATGCGAGC_Normoxia"',
#  '"AACCATTAGGCT_Normoxia"',
#  '"AACCATTCAGGC_Normoxia"',
#  '"AACCCAACCGCC_Normoxia"',
#  '"AACCCCGCAGTC_Normoxia"',
#  '"AACCCGTCAAAT_Normoxia"',
#  '"AACCCGTCACCT_Normoxia"',
#  '"AACCCTCACATT_Normoxia"',
#  '"AACCCTGTTCAA_Normoxia"',
#  '"AACCCTTGGCCC_Normoxia"',
#  '"AACCGCCGACCA_Normoxia"',
#  '"AACCGCCGGGTT_Normoxia"',
#  '"AACCGCCTCATT_Normoxia"',
#  '"AACCGGACCAAT_Normoxia"',
#  '"AACCGGCCCAAC_Normoxia"',
#  '"AACCGTAAAGGA_Normoxia"',
#  '"AACCGTCACACG_Normoxia"',
#  '"AACCGTCATTGA_Normoxia"',
#  '"AACCGTCCTATA_Normoxia"',
#  '"AACCGTCGTGGA_Normoxia"',
#  '"AACCTAATCTCT_Normoxia"',
#  '"AACCTATCGACG_Normoxia"',
#  '"AACCTATCGGCC_Normoxia"',
#  '"AACCTCCTTGCC_Normoxia"',
#  '"AACCTGACTCTT_Normoxia"',
#  '"AACCTGACTTTG_Normoxia"',
#  '"AACCTGCGAGAG_Normoxia"',
#  '"AACCTGTGTCCT_Normoxia"',
#  '"AACCTTACGCGC_Normoxia"',
#  '"AACCTTGGGAAC_Normoxia"',
#  '"AACCTTGTTGCT_Normoxia"',
#  '"AACGAAACTGTG_Normoxia"',
#  '"AACGATAGATGA_Normoxia"',
#  '"AACGATGGCCGC_Normoxia"',
#  '"AACGCATGTGAT_Normoxia"',
#  '"AACGCCATTGCC_Normoxia"',
#  '"AACGCCCAGCTC_Normoxia"',
#  '"AACGCCCGACTA_Normoxia"',
#  '"AACGCCGGGTGG_Normoxia"',
#  '"AACGCCTTTCTG_Normoxia"',
#  '"AACGCGCGCTGC_Normoxia"',
#  '"AACGCGGGGACG_Normoxia"',
#  '"AACGCGTCCTAG_Normoxia"',
#  '"AACGCGTGTGAT_Normoxia"',
#  '"AACGCTCATACT_Normoxia"',
#  '"AACGCTGACACG_Normoxia"',
#  '"AACGCTGTACAT_Normoxia"',
#  '"AACGCTGTGGGT_Normoxia"',
#  '"AACGGAAGGTAT_Normoxia"',
#  '"AACGGAATAGGT_Normoxia"',
#  '"AACGGAGCGCTA_Normoxia"',
#  '"AACGGATCGATA_Normoxia"',
#  '"AACGGCAATATC_Normoxia"',
#  '"AACGGCACCCTG_Normoxia"',
#  '"AACGGCACGAGT_Normoxia"',
#  '"AACGGCCAAACG_Normoxia"',
#  '"AACGGCCACCTG_Normoxia"',
#  '"AACGGCCCACTG_Normoxia"',
#  '"AACGGCCCCCAA_Normoxia"',
#  '"AACGGCCCCCAC_Normoxia"',
#  '"AACGGCCCCCCA_Normoxia"',
#  '"AACGGCCCCCCC_Normoxia"',
#  '"AACGGCCCCCCG_Normoxia"',
#  '"AACGGCCCCCCT_Normoxia"',
#  '"AACGGCCCCCGC_Normoxia"',
#  '"AACGGCCCCCGG_Normoxia"',
#  '"AACGGCCCCCTA_Normoxia"',
#  '"AACGGCCCCCTC_Normoxia"',
#  '"AACGGCCCCTGC_Normoxia"',
#  '"AACGGCCCCTGT_Normoxia"',
#  '"AACGGCCCGGTA_Normoxia"',
#  '"AACGGCCCTGCT_Normoxia"',
#  '"AACGGCCGAGGG_Normoxia"',
#  '"AACGGCCTTGGA_Normoxia"',
#  '"AACGGCCTTGTG_Normoxia"',
#  '"AACGGCGCATTT_Normoxia"',
#  '"AACGGCGCGCCT_Normoxia"',
#  '"AACGGCGTCCTG_Normoxia"',
#  '"AACGGCTCTTGG_Normoxia"',
#  '"AACGGCTGCCGC_Normoxia"',
#  '"AACGGCTGCTGT_Normoxia"',
#  '"AACGGGACCCCC_Normoxia"',
#  '"AACGGGTGTTGC_Normoxia"',
#  '"AACGGTCAAACT_Normoxia"',
#  '"AACGGTGGACCA_Normoxia"',
#  '"AACGGTGTCCAA_Normoxia"',
#  '"AACGGTTCAAGT_Normoxia"',
#  '"AACGGTTCCATC_Normoxia"',
#  '"AACGGTTTCCTC_Normoxia"',
#  '"AACGTAAGCGGC_Normoxia"',
#  '"AACGTACTGTGG_Normoxia"',
#  '"AACGTCCGTCCA_Normoxia"',
#  '"AACGTCCGTGGT_Normoxia"',
#  '"AACGTCGACCAT_Normoxia"',
#  '"AACGTGCGTACA_Normoxia"',
#  '"AACGTGGGTGAA_Normoxia"',
#  '"AACGTGTCATGG_Normoxia"',
#  '"AACGTGTCTGGC_Normoxia"',
#  '"AACTAAGCGCTG_Normoxia"',
#  '"AACTACAGTTTT_Normoxia"',
#  '"AACTAGTAGTGG_Normoxia"',
#  '"AACTAGTCTCTC_Normoxia"',
#  '"AACTAGTTCATC_Normoxia"',
#  '"AACTATCTAAAC_Normoxia"',
#  '"AACTATTGGGTT_Normoxia"',
#  '"AACTCACCTTAG_Normoxia"',
#  '"AACTCACGCTTG_Normoxia"',
#  '"AACTCACTTCCG_Normoxia"',
#  '"AACTCATGGAAG_Normoxia"',
#  '"AACTCCCGCCTC_Normoxia"',
#  '"AACTCCCTCCTC_Normoxia"',
#  '"AACTCCCTTCCT_Normoxia"',
#  '"AACTCCTAGGGG_Normoxia"',
#  '"AACTCCTGGTTA_Normoxia"',
#  '"AACTCGATTGCG_Normoxia"',
#  '"AACTCGGGACCG_Normoxia"',
#  '"AACTCGGGGCAA_Normoxia"',
#  '"AACTCGGGTCAA_Normoxia"',
#  '"AACTCGTACAAT_Normoxia"',
#  '"AACTCGTACTAT_Normoxia"',
#  '"AACTCGTGGGGG_Normoxia"',
#  '"AACTCTCCAGGA_Normoxia"',
#  '"AACTCTTGCAAG_Normoxia"',
#  '"AACTGACCAGCC_Normoxia"',
#  '"AACTGAGACCTA_Normoxia"',
#  '"AACTGCAGCAAG_Normoxia"',
#  '"AACTGCCCTCGG_Normoxia"',
#  '"AACTGCTGACCC_Normoxia"',
#  '"AACTGGGAGTCC_Normoxia"',
#  '"AACTGGGCGGTA_Normoxia"',
#  '"AACTGGTCGCAA_Normoxia"',
#  '"AACTGTAAGAAA_Normoxia"',
#  '"AACTGTATTATG_Normoxia"',
#  '"AACTTACGTGGT_Normoxia"',
#  '"AACTTACTTTTG_Normoxia"',
#  '"AACTTATGATCG_Normoxia"',
#  '"AACTTCCGCGAC_Normoxia"',
#  '"AACTTGCCCTCG_Normoxia"',
#  '"AACTTGCCGGCG_Normoxia"',
#  '"AACTTGCGTGAG_Normoxia"',
#  '"AACTTGGCCGAA_Normoxia"',
#  '"AACTTGTTTTGA_Normoxia"',
#  '"AACTTTGCCCAT_Normoxia"',
#  '"AAGAAATCTCCC_Normoxia"',
#  '"AAGAACAACACC_Normoxia"',
#  '"AAGAACGACGTC_Normoxia"',
#  '"AAGAAGGCAACT_Normoxia"',
#  '"AAGAATGTCGTC_Normoxia"',
#  '"AAGAATTCCGTA_Normoxia"',
#  '"AAGACAAGAGAT_Normoxia"',
#  '"AAGACCAGTCGG_Normoxia"',
#  '"AAGACCCATAGG_Normoxia"',
#  '"AAGACCTGTTCT_Normoxia"',
#  '"AAGACGCCCACT_Normoxia"',
#  '"AAGAGACTGGGC_Normoxia"',
#  '"AAGAGCACTGGC_Normoxia"',
#  '"AAGAGCCCGCAT_Normoxia"',
#  '"AAGAGGTCACCG_Normoxia"',
#  '"AAGAGTCGAAGG_Normoxia"',
#  '"AAGATCCGTAGG_Normoxia"',
#  '"AAGATGTCGAGG_Normoxia"',
#  '"AAGCAAACCCTC_Normoxia"',
#  '"AAGCAATCCGTC_Normoxia"',
#  '"AAGCACACGGTC_Normoxia"',
#  '"AAGCACCCCCGA_Normoxia"',
#  '"AAGCACCCGGTC_Normoxia"',
#  '"AAGCACGCCCTA_Normoxia"',
#  '"AAGCACGCCTAT_Normoxia"',
#  '"AAGCACGTTTAT_Normoxia"',
#  '"AAGCAGTTTGTC_Normoxia"',
#  '"AAGCATGTGGCT_Normoxia"',
#  '"AAGCCACGGTCC_Normoxia"',
#  '"AAGCCATGATCC_Normoxia"',
#  '"AAGCCCAATCCA_Normoxia"',
#  '"AAGCCCAGCGCG_Normoxia"',
#  '"AAGCCCTGACTG_Normoxia"',
#  '"AAGCCGACAGCA_Normoxia"',
#  '"AAGCCGATAGCC_Normoxia"',
#  '"AAGCCGCAATAT_Normoxia"',
#  '"AAGCCGCCTTAT_Normoxia"',
#  '"AAGCCGTATGCC_Normoxia"',
#  '"AAGCCGTCTACA_Normoxia"',
#  '"AAGCCTCCCGTC_Normoxia"',
#  '"AAGCCTCCGTCT_Normoxia"',
#  '"AAGCCTGCCCGA_Normoxia"',
#  '"AAGCCTGTTCTT_Normoxia"',
#  '"AAGCGAACGAAC_Normoxia"',
#  '"AAGCGAATAGAC_Normoxia"',
#  '"AAGCGACCAAGG_Normoxia"',
#  '"AAGCGAGCGCGA_Normoxia"',
#  '"AAGCGCAATAGT_Normoxia"',
#  '"AAGCGCACTCGT_Normoxia"',
#  '"AAGCGCAGCTGG_Normoxia"',
#  '"AAGCGCATTTGG_Normoxia"',
#  '"AAGCGCCCGGAA_Normoxia"',
#  '"AAGCGCCTCCGG_Normoxia"',
#  '"AAGCGCGACTAC_Normoxia"',
#  '"AAGCGCGATGCA_Normoxia"',
#  '"AAGCGCGCTGCA_Normoxia"',
#  '"AAGCGCGGCTGC_Normoxia"',
#  '"AAGCGGAGCGGT_Normoxia"',
#  '"AAGCGGGCCGGT_Normoxia"',
#  '"AAGCGGTACGGA_Normoxia"',
#  '"AAGCGGTATGGT_Normoxia"',
#  '"AAGCGTCCATCG_Normoxia"',
#  '"AAGCGTCGTCAC_Normoxia"',
#  '"AAGCGTGAGCCG_Normoxia"',
#  '"AAGCGTTACGCA_Normoxia"',
#  '"AAGCTACTACCA_Normoxia"',
#  '"AAGCTGAACCCA_Normoxia"',
#  '"AAGCTGGCGGCT_Normoxia"',
#  '"AAGCTTAGACAT_Normoxia"',
#  '"AAGGAATATTGA_Normoxia"',
#  '"AAGGAATTGGAG_Normoxia"',
#  '"AAGGACCTTCAG_Normoxia"',
#  '"AAGGACTAATGT_Normoxia"',
#  '"AAGGAGGGACCG_Normoxia"',
#  '"AAGGATCATTTC_Normoxia"',
#  '"AAGGATCCCGCT_Normoxia"',
#  '"AAGGCACTTTGC_Normoxia"',
#  '"AAGGCCATTAGG_Normoxia"',
#  '"AAGGCCCCTACA_Normoxia"',
#  '"AAGGCCCGGATT_Normoxia"',
#  '"AAGGCCCGTGAG_Normoxia"',
#  '"AAGGCGAAGCGT_Normoxia"',
#  '"AAGGCGCGTTTA_Normoxia"',
#  '"AAGGCGGCTAGG_Normoxia"',
#  '"AAGGCGGGAACC_Normoxia"',
#  '"AAGGCTTAGTTC_Normoxia"',
#  '"AAGGGATGACAG_Normoxia"',
#  '"AAGGGCCCCCAG_Normoxia"',
#  '"AAGGGGAGTTAT_Normoxia"',
#  '"AAGGGTGATCAT_Normoxia"',
#  '"AAGGTAATTAGG_Normoxia"',
#  '"AAGGTACCCTCC_Normoxia"',
#  '"AAGGTCCAGCTC_Normoxia"',
#  '"AAGGTCCGCCGG_Normoxia"',
#  '"AAGGTCCGGGTT_Normoxia"',
#  '"AAGGTCTTCTAC_Normoxia"',
#  '"AAGGTGTGACTG_Normoxia"',
#  '"AAGGTGTTTGTC_Normoxia"',
#  '"AAGGTTAGGTGG_Normoxia"',
#  '"AAGGTTCTGACC_Normoxia"',
#  '"AAGTAACGTCCT_Normoxia"',
#  '"AAGTAACTTGCT_Normoxia"',
#  '"AAGTAAGATACC_Normoxia"',
#  '"AAGTAATGCACC_Normoxia"',
#  '"AAGTACGCGCCG_Normoxia"',
#  '"AAGTACGCTGAT_Normoxia"',
#  '"AAGTAGGGGCAT_Normoxia"',
#  '"AAGTCAAGAATG_Normoxia"',
#  '"AAGTCACGAGCT_Normoxia"',
#  '"AAGTCAGCTCCC_Normoxia"',
#  '"AAGTCAGGTGCA_Normoxia"',
#  '"AAGTCCATGCCT_Normoxia"',
#  '"AAGTCCGAGCCT_Normoxia"',
#  '"AAGTCCTTGGTA_Normoxia"',
#  '"AAGTCGACGAGG_Normoxia"',
#  '"AAGTCGCGTAAC_Normoxia"',
#  '"AAGTCGGATCTC_Normoxia"',
#  '"AAGTCTAGAGAG_Normoxia"',
#  '"AAGTCTTATATT_Normoxia"',
#  '"AAGTCTTTGCTC_Normoxia"',
#  '"AAGTGACGTGGA_Normoxia"',
#  '"AAGTGATGGAAT_Normoxia"',
#  '"AAGTGCACATAA_Normoxia"',
#  '"AAGTGCCCGTAC_Normoxia"',
#  '"AAGTGCCTCCAC_Normoxia"',
#  '"AAGTGCCTCCCA_Normoxia"',
#  '"AAGTGCCTCCCC_Normoxia"',
#  '"AAGTGCCTCCCT_Normoxia"',
#  '"AAGTGCGACGCT_Normoxia"',
#  '"AAGTGCTCGACT_Normoxia"',
#  '"AAGTGGTGGGGA_Normoxia"',
#  '"AAGTGTAAACGC_Normoxia"',
#  '"AAGTGTAACGCC_Normoxia"',
#  '"AAGTGTCGCTTA_Normoxia"',
#  '"AAGTGTGAGGCC_Normoxia"',
#  '"AAGTGTTTCACA_Normoxia"',
#  '"AAGTGTTTTCTT_Normoxia"',
#  '"AAGTTAACCGGT_Normoxia"',
#  '"AAGTTCCATTCG_Normoxia"',
#  '"AAGTTCTTCCGC_Normoxia"',
#  '"AAGTTGCCGCTA_Normoxia"',
#  '"AAGTTTCTTTCC_Normoxia"',
#  '"AATAACGTCACT_Normoxia"',
#  '"AATAAGTTCGTG_Normoxia"',
#  '"AATACAACGACC_Normoxia"',
#  '"AATACATCCTGT_Normoxia"',
#  '"AATACCAGCGGA_Normoxia"',
#  '"AATACCTAGGCG_Normoxia"',
#  '"AATACCTGATAG_Normoxia"',
#  '"AATACGGAACCG_Normoxia"',
#  '"AATACGGCCTAG_Normoxia"',
#  '"AATACTAGTGCA_Normoxia"',
#  '"AATAGAGCAGTT_Normoxia"',
#  '"AATAGATCCGAA_Normoxia"',
#  '"AATAGCTTATAA_Normoxia"',
#  '"AATAGGGCTGCC_Normoxia"',
#  '"AATATGCATACG_Normoxia"',
#  '"AATCACAAGCAA_Normoxia"',
#  '"AATCAGAAGGCC_Normoxia"',
#  '"AATCATTCCTTC_Normoxia"',
#  '"AATCCAACCAAT_Normoxia"',
#  '"AATCCAATGGCA_Normoxia"',
#  '"AATCCAGCCCAA_Normoxia"',
#  '"AATCCAGCGACC_Normoxia"',
#  '"AATCCCGACTTC_Normoxia"',
#  '"AATCCCGTTCCC_Normoxia"',
#  '"AATCCCTTGACC_Normoxia"',
#  '"AATCCGAAGGAG_Normoxia"',
#  '"AATCCGACGCCA_Normoxia"',
#  '"AATCCGAGTAGC_Normoxia"',
#  '"AATCCGCTCCGA_Normoxia"',
#  '"AATCCGGTTGGC_Normoxia"',
#  '"AATCCGTATGCC_Normoxia"',
#  '"AATCGAGATGGA_Normoxia"',
#  '"AATCGCCCCCCA_Normoxia"',
#  '"AATCGCCTCGGG_Normoxia"',
#  '"AATCGGACAACG_Normoxia"',
#  '"AATCGGTCCTTG_Normoxia"',
#  '"AATCGTTCTCCA_Normoxia"',
#  '"AATCTAGGCTTC_Normoxia"',
#  '"AATCTATCTACA_Normoxia"',
#  '"AATCTCGTTCGA_Normoxia"',
#  '"AATCTGACGAAG_Normoxia"',
#  '"AATCTTCCTTCC_Normoxia"',
#  '"AATCTTCCTTCT_Normoxia"',
#  '"AATCTTTCTCGT_Normoxia"',
#  '"AATGAAAAGACT_Normoxia"',
#  '"AATGAACTACGT_Normoxia"',
#  '"AATGACGCTAGC_Normoxia"',
#  '"AATGAGCGTCCG_Normoxia"',
#  '"AATGCAAGGTCG_Normoxia"',
#  '"AATGCAGGAAGC_Normoxia"',
#  '"AATGCCCGCGCG_Normoxia"',
#  '"AATGCCCTGTCC_Normoxia"',
#  '"AATGCCCTGTCG_Normoxia"',
#  '"AATGCCCTGTCT_Normoxia"',
#  '"AATGCCTGCCAA_Normoxia"',
#  '"AATGCCTGTTGA_Normoxia"',
#  '"AATGCCTTCGGG_Normoxia"',
#  '"AATGCGCCATGC_Normoxia"',
#  '"AATGCGGGTGAC_Normoxia"',
#  '"AATGCGGTGGTG_Normoxia"',
#  '"AATGCTCGAGAA_Normoxia"',
#  '"AATGCTTATCTC_Normoxia"',
#  '"AATGGACCTCGC_Normoxia"',
#  '"AATGGACGAAGC_Normoxia"',
#  '"AATGGCCCTGTC_Normoxia"',
#  '"AATGGCCGATCC_Normoxia"',
#  '"AATGGCGCCTAT_Normoxia"',
#  '"AATGGGATAGCA_Normoxia"',
#  '"AATGGTCCCTCG_Normoxia"',
#  '"AATGTACCCCCG_Normoxia"',
#  '"AATGTGATGGAT_Normoxia"',
#  '"AATGTGCAGCGA_Normoxia"',
#  '"AATGTTCAGATA_Normoxia"',
#  '"AATGTTGGGTGC_Normoxia"',
#  '"AATTACCGCGTT_Normoxia"',
#  '"AATTACTGATAT_Normoxia"',
#  '"AATTCAACGACG_Normoxia"',
#  '"AATTCCATTCGA_Normoxia"',
#  '"AATTCCTGTTCT_Normoxia"',
#  '"AATTGACCCGTA_Normoxia"',
#  '"AATTGCCCTCTC_Normoxia"',
#  '"AATTGCGAGGCT_Normoxia"',
#  '"AATTGCGCGCTA_Normoxia"',
#  '"AATTGGCCCGAC_Normoxia"',
#  '"AATTGGGCGCAA_Normoxia"',
#  '"AATTGGTGAGCT_Normoxia"',
#  '"AATTGTTGGGCG_Normoxia"',
#  '"AATTTACGTTCG_Normoxia"',
#  '"AATTTAGTGTCC_Normoxia"',
#  '"AATTTGAAATGC_Normoxia"',
#  '"AATTTGCGGCTC_Normoxia"',
#  '"AATTTGTATAGC_Normoxia"',
#  '"AATTTTGCAATG_Normoxia"',
#  '"ACAAAATCAAGG_Normoxia"',
#  '"ACAAACAGAGGT_Normoxia"',
#  '"ACAAACTCCGTC_Normoxia"',
#  '"ACAAAGCTCTGA_Normoxia"',
#  '"ACAACAAATTCG_Normoxia"',
#  '"ACAACTGAGTAG_Normoxia"',
#  '"ACAACTGCGCCT_Normoxia"',
#  '"ACAACTTCAGCC_Normoxia"',
#  '"ACAACTTGCGCC_Normoxia"',
#  '"ACAACTTTGCCT_Normoxia"',
#  '"ACAACTTTGGCC_Normoxia"',
#  '"ACAAGGCCATTC_Normoxia"',
#  '"ACAAGGCGGGGC_Normoxia"',
#  '"ACAAGTACTGGC_Normoxia"',
#  '"ACAATAACCATC_Normoxia"',
#  '"ACAATGACCCGC_Normoxia"',
#  '"ACAATGGTCGAT_Normoxia"',
#  '"ACACAACTCTTT_Normoxia"',
#  '"ACACACAGGTAT_Normoxia"',
#  '"ACACACCATGCA_Normoxia"',
#  '"ACACACCGCAGG_Normoxia"',
#  '"ACACACGTTTAG_Normoxia"',
#  '"ACACAGACGTGC_Normoxia"',
#  '"ACACAGTGTATG_Normoxia"',
#  '"ACACAGTTCCCC_Normoxia"',
#  '"ACACATAGTGTC_Normoxia"',
#  '"ACACCAAGGGGT_Normoxia"',
#  '"ACACCACGCGAC_Normoxia"',
#  '"ACACCAGGGCAG_Normoxia"',
#  '"ACACCCCGCCTG_Normoxia"',
#  '"ACACCCCGTCAG_Normoxia"',
#  '"ACACCCCGTTCC_Normoxia"',
#  '"ACACCCCTGGCG_Normoxia"',
#  '"ACACCCGTACGG_Normoxia"',
#  '"ACACCCTTCGAA_Normoxia"',
#  '"ACACCGCTCGGC_Normoxia"',
#  '"ACACCGGCTGGC_Normoxia"',
#  '"ACACCGGGGGAT_Normoxia"',
#  '"ACACCGGGTTCA_Normoxia"',
#  '"ACACCGGTTCCC_Normoxia"',
#  '"ACACCTTCCTGG_Normoxia"',
#  '"ACACCTTGACCT_Normoxia"',
#  '"ACACCTTGGAAC_Normoxia"',
#  '"ACACGCATACGC_Normoxia"',
#  '"ACACGCCCAGCA_Normoxia"',
#  '"ACACGCGGGTAG_Normoxia"',
#  '"ACACGCTACACA_Normoxia"',
#  '"ACACGCTTGTTC_Normoxia"',
#  '"ACACGTTTCACT_Normoxia"',
#  '"ACACTACTCCAT_Normoxia"',
#  '"ACACTATCGCTC_Normoxia"',
#  '"ACACTCGCAGCC_Normoxia"',
#  '"ACACTTCATGGG_Normoxia"',
#  '"ACACTTCCTTCT_Normoxia"',
#  '"ACACTTCGATAT_Normoxia"',
#  '"ACAGAAACCCTC_Normoxia"',
#  '"ACAGAACCCTCC_Normoxia"',
#  '"ACAGACAGGTAG_Normoxia"',
#  '"ACAGACCCGCAA_Normoxia"',
#  '"ACAGACCCTCCT_Normoxia"',
#  '"ACAGACTCACGT_Normoxia"',
#  '"ACAGAGAACAGC_Normoxia"',
#  '"ACAGAGCAGCCG_Normoxia"',
#  '"ACAGAGTATTCC_Normoxia"',
#  '"ACAGAGTCGCCC_Normoxia"',
#  '"ACAGATACCAAC_Normoxia"',
#  '"ACAGATCTTGGT_Normoxia"',
#  '"ACAGATTAGTGC_Normoxia"',
#  '"ACAGCAAAATGC_Normoxia"',
#  '"ACAGCACGCTCG_Normoxia"',
#  '"ACAGCAGATTGT_Normoxia"',
#  '"ACAGCAGGGCTG_Normoxia"',
#  '"ACAGCCGAGACC_Normoxia"',
#  '"ACAGCCGGCCGA_Normoxia"',
#  '"ACAGCGCGCTAG_Normoxia"',
#  '"ACAGCGTAAAGA_Normoxia"',
#  '"ACAGCTCGGCCT_Normoxia"',
#  '"ACAGCTGTCAGA_Normoxia"',
#  '"ACAGGACCTGGG_Normoxia"',
#  '"ACAGGAGTCCAA_Normoxia"',
#  '"ACAGGATGCGTA_Normoxia"',
#  '"ACAGGCAGCCAT_Normoxia"',
#  '"ACAGGCCCGCCA_Normoxia"',
#  '"ACAGGCGCACGA_Normoxia"',
#  '"ACAGGGCATTGT_Normoxia"',
#  '"ACAGGGCTCAAT_Normoxia"',
#  '"ACAGGTAGCGAG_Normoxia"',
#  '"ACAGGTATAGGA_Normoxia"',
#  '"ACAGGTATGGTT_Normoxia"',
#  '"ACAGTACACCAA_Normoxia"',
#  '"ACAGTCACCCTC_Normoxia"',
#  '"ACAGTGCCGGTT_Normoxia"',
#  '"ACAGTGCTCCTG_Normoxia"',
#  '"ACAGTGGTGCGA_Normoxia"',
#  '"ACAGTGTAAATG_Normoxia"',
#  '"ACAGTGTAGTGT_Normoxia"',
#  '"ACAGTTCCTTAG_Normoxia"',
#  '"ACATAAAATTCG_Normoxia"',
#  '"ACATACGTCCCC_Normoxia"',
#  '"ACATACTTACAA_Normoxia"',
#  '"ACATATCCTTCA_Normoxia"',
#  '"ACATCACGCGTT_Normoxia"',
#  '"ACATCATTCTCA_Normoxia"',
#  '"ACATCCTCGCCG_Normoxia"',
#  '"ACATCCTGCCGG_Normoxia"',
#  '"ACATCGAACCTG_Normoxia"',
#  '"ACATCGATCCCC_Normoxia"',
#  '"ACATCGATTGAT_Normoxia"',
#  '"ACATCTGTTCCC_Normoxia"',
#  '"ACATCTTGCTAG_Normoxia"',
#  '"ACATGACACCTC_Normoxia"',
#  '"ACATGATCTCCG_Normoxia"',
#  '"ACATGGAAACCC_Normoxia"',
#  '"ACATGGCAGCGA_Normoxia"',
#  '"ACATGTCAGTTG_Normoxia"',
#  '"ACATGTGGCCTT_Normoxia"',
#  '"ACATGTTTTAAT_Normoxia"',
#  '"ACATTAATGAAG_Normoxia"',
#  '"ACATTAGCCCGC_Normoxia"',
#  '"ACATTCCGGCAG_Normoxia"',
#  '"ACATTCGAGGCA_Normoxia"',
#  '"ACATTCGAGTAA_Normoxia"',
#  '"ACATTTGTTGTG_Normoxia"',
#  '"ACATTTTGAAAG_Normoxia"',
#  '"ACCAAAACCGTG_Normoxia"',
#  '"ACCAAAAGAGGC_Normoxia"',
#  '"ACCAAACTTTCA_Normoxia"',
#  '"ACCAAATAAGGG_Normoxia"',
#  '"ACCAACAAATCC_Normoxia"',
#  '"ACCAACACTTTC_Normoxia"',
#  '"ACCAACCGTCAA_Normoxia"',
#  '"ACCAACCTGTCA_Normoxia"',
#  '"ACCAACTCAAGG_Normoxia"',
#  '"ACCAACTTCGTT_Normoxia"',
#  '"ACCAAGGAATGG_Normoxia"',
#  '"ACCAAGGCCGCG_Normoxia"',
#  '"ACCAAGGGGAGA_Normoxia"',
#  '"ACCAAGGTCCTA_Normoxia"',
#  '"ACCAAGTGAGTG_Normoxia"',
#  '"ACCAATATGTGA_Normoxia"',
#  '"ACCAATTATTCG_Normoxia"',
#  '"ACCAATTGGAGC_Normoxia"',
#  '"ACCAATTGTGAA_Normoxia"',
#  '"ACCACAAGCGCA_Normoxia"',
#  '"ACCACACGCAGT_Normoxia"',
#  '"ACCACACGTCGT_Normoxia"',
#  '"ACCACCAAACAT_Normoxia"',
#  '"ACCACCACACTA_Normoxia"',
#  '"ACCACCACAGGA_Normoxia"',
#  '"ACCACCGTGACA_Normoxia"',
#  '"ACCACGACCTCG_Normoxia"',
#  '"ACCACGTTAGAC_Normoxia"',
#  '"ACCACTAGGCAT_Normoxia"',
#  '"ACCACTCATCTT_Normoxia"',
#  '"ACCACTCCTCGA_Normoxia"',
#  '"ACCACTCGTACA_Normoxia"',
#  '"ACCAGAGGCTCC_Normoxia"',
#  '"ACCAGATCAGCA_Normoxia"',
#  '"ACCAGATGCTTG_Normoxia"',
#  '"ACCAGCACCCCC_Normoxia"',
#  '"ACCAGCCCGAGA_Normoxia"',
#  '"ACCAGGAAAGCC_Normoxia"',
#  '"ACCAGGTTGTCA_Normoxia"',
#  '"ACCAGTAAGGGC_Normoxia"',
#  '"ACCAGTACCGTG_Normoxia"',
#  '"ACCAGTGCTCCA_Normoxia"',
#  '"ACCAGTTTCAGG_Normoxia"',
#  '"ACCAGTTTTCGG_Normoxia"',
#  '"ACCATACGCGGC_Normoxia"',
#  '"ACCATACTAACT_Normoxia"',
#  '"ACCATATGGCAT_Normoxia"',
#  '"ACCATCACGTTC_Normoxia"',
#  '"ACCATCGTTTCG_Normoxia"',
#  '"ACCATCTGTTCT_Normoxia"',
#  '"ACCATGCCCCGG_Normoxia"',
#  '"ACCATGGTCACG_Normoxia"',
#  '"ACCCAAGAAAAT_Normoxia"',
#  '"ACCCAATTATCA_Normoxia"',
#  '"ACCCAATTGCAC_Normoxia"',
#  '"ACCCACAGCCTA_Normoxia"',
#  '"ACCCACGGTTAT_Normoxia"',
#  '"ACCCACGTCACA_Normoxia"',
#  '"ACCCACTTGGCG_Normoxia"',
#  '"ACCCAGCACAAT_Normoxia"',
#  '"ACCCAGTCACGT_Normoxia"',
#  '"ACCCAGTGTGGC_Normoxia"',
#  '"ACCCAGTGTTGT_Normoxia"',
#  '"ACCCATGGATAG_Normoxia"',
#  '"ACCCATGGCACG_Normoxia"',
#  '"ACCCCAAATCAG_Normoxia"',
#  '"ACCCCAAATTCG_Normoxia"',
#  '"ACCCCACCTCCT_Normoxia"',
#  '"ACCCCACCTTCT_Normoxia"',
#  '"ACCCCACCTTTT_Normoxia"',
#  '"ACCCCACTTTCA_Normoxia"',
#  '"ACCCCAGCGTCG_Normoxia"',
#  '"ACCCCAGGACGA_Normoxia"',
#  '"ACCCCAGGTCTA_Normoxia"',
#  '"ACCCCATTTCAG_Normoxia"',
#  '"ACCCCCAGCCCG_Normoxia"',
#  '"ACCCCCATAAAC_Normoxia"',
#  '"ACCCCCATGCGT_Normoxia"',
#  '"ACCCCCCCCGGT_Normoxia"',
#  '"ACCCCCCCTGTA_Normoxia"',
#  '"ACCCCCCGGCGT_Normoxia"',
#  '"ACCCCCCGTAAA_Normoxia"',
#  '"ACCCCCTCCAGA_Normoxia"',
#  '"ACCCCGATCGGA_Normoxia"',
#  '"ACCCCGCATGCG_Normoxia"',
#  '"ACCCCGCCGAAC_Normoxia"',
#  '"ACCCCGCGTGTT_Normoxia"',
#  '"ACCCCGGCGGGA_Normoxia"',
#  '"ACCCCGGTCAGC_Normoxia"',
#  '"ACCCCTAGCGCG_Normoxia"',
#  '"ACCCCTCTCGAG_Normoxia"',
#  '"ACCCGAAGTTAA_Normoxia"',
#  '"ACCCGAGAGAAC_Normoxia"',
#  '"ACCCGAGTAGGC_Normoxia"',
#  '"ACCCGCACATTT_Normoxia"',
#  '"ACCCGCCAGCAG_Normoxia"',
#  '"ACCCGCCCAATG_Normoxia"',
#  '"ACCCGCCCCACC_Normoxia"',
#  '"ACCCGCGACCCA_Normoxia"',
#  '"ACCCGCGTCATT_Normoxia"',
#  '"ACCCGCTAATGG_Normoxia"',
#  '"ACCCGGAAGATA_Normoxia"',
#  '"ACCCGGAAGCCG_Normoxia"',
#  '"ACCCGTCCAGTA_Normoxia"',
#  '"ACCCGTGCAGTC_Normoxia"',
#  '"ACCCTACTATTA_Normoxia"',
#  '"ACCCTAGCCATC_Normoxia"',
#  '"ACCCTCACCTCA_Normoxia"',
#  '"ACCCTCATCCTT_Normoxia"',
#  '"ACCCTCTTAATA_Normoxia"',
#  '"ACCCTCTTTGCT_Normoxia"',
#  '"ACCCTGACGATA_Normoxia"',
#  '"ACCCTGCACGTG_Normoxia"',
#  '"ACCCTGCCTAAA_Normoxia"',
#  '"ACCCTGTTGCCT_Normoxia"',
#  '"ACCCTTCCCAGC_Normoxia"',
#  '"ACCCTTTACCGC_Normoxia"',
#  '"ACCGAAGCCAGT_Normoxia"',
#  '"ACCGACTAGTTA_Normoxia"',
#  '"ACCGAGATGCCC_Normoxia"',
#  '"ACCGATATCTTA_Normoxia"',
#  '"ACCGATCGGCTG_Normoxia"',
#  '"ACCGATGTGCCG_Normoxia"',
#  '"ACCGCAAAAGAT_Normoxia"',
#  '"ACCGCAAGGATC_Normoxia"',
#  '"ACCGCAAGTTCC_Normoxia"',
#  '"ACCGCAGGTCTG_Normoxia"',
#  '"ACCGCCACTGGC_Normoxia"',
#  '"ACCGCCAGTAGG_Normoxia"',
#  '"ACCGCCATGTGG_Normoxia"',
#  '"ACCGCCCCCAAG_Normoxia"',
#  '"ACCGCCCGCCAG_Normoxia"',
#  '"ACCGCCGCAAGG_Normoxia"',
#  '"ACCGCCGGGAAA_Normoxia"',
#  '"ACCGCCTAATTG_Normoxia"',
#  '"ACCGCCTCCCCC_Normoxia"',
#  '"ACCGCGCACCTG_Normoxia"',
#  '"ACCGCGCCGTTG_Normoxia"',
#  '"ACCGCGCGGACT_Normoxia"',
#  '"ACCGCGGATAGC_Normoxia"',
#  '"ACCGCGTCGGGG_Normoxia"',
#  '"ACCGCTAAACTC_Normoxia"',
#  '"ACCGCTAAGTAA_Normoxia"',
#  '"ACCGCTCAGCTC_Normoxia"',
#  '"ACCGCTCTCGCG_Normoxia"',
#  '"ACCGCTGGTTAA_Normoxia"',
#  '"ACCGGATTGGCT_Normoxia"',
#  '"ACCGGCAAGTGG_Normoxia"',
#  '"ACCGGCAGGTGA_Normoxia"',
#  '"ACCGGCCCCCTG_Normoxia"',
#  '"ACCGGCGATGGT_Normoxia"',
#  '"ACCGGCGCATTG_Normoxia"',
#  '"ACCGGCTAACCG_Normoxia"',
#  '"ACCGGCTATTTC_Normoxia"',
#  '"ACCGGCTCCTTT_Normoxia"',
#  '"ACCGGGACCCCT_Normoxia"',
#  '"ACCGGGATGAGT_Normoxia"',
#  '"ACCGGGGGCCGC_Normoxia"',
#  '"ACCGGGTGCGCA_Normoxia"',
#  '"ACCGGTAATCAT_Normoxia"',
#  '"ACCGGTGGCAGC_Normoxia"',
#  '"ACCGGTGGGACG_Normoxia"',
#  '"ACCGTATGTCCC_Normoxia"',
#  '"ACCGTCAACAAT_Normoxia"',
#  '"ACCGTCACAGTC_Normoxia"',
#  '"ACCGTCCGAAAG_Normoxia"',
#  '"ACCGTCGGAGCC_Normoxia"',
#  '"ACCGTCGGTCTG_Normoxia"',
#  '"ACCGTGAGGCGG_Normoxia"',
#  '"ACCGTGCATGCC_Normoxia"',
#  '"ACCGTTGCCGTG_Normoxia"',
#  '"ACCGTTGTCCCG_Normoxia"',
#  '"ACCGTTTGATTA_Normoxia"',
#  '"ACCTAACGCGGT_Normoxia"',
#  '"ACCTACAACTGG_Normoxia"',
#  '"ACCTACAACTTA_Normoxia"',
#  '"ACCTACAGGCGG_Normoxia"',
#  '"ACCTACCATCAA_Normoxia"',
#  '"ACCTAGTTTTAG_Normoxia"',
#  '"ACCTATAGCAAA_Normoxia"',
#  '"ACCTCAACGGGG_Normoxia"',
#  '"ACCTCACGCGGT_Normoxia"',
#  '"ACCTCAGCCTTA_Normoxia"',
#  '"ACCTCAGGTATC_Normoxia"',
#  '"ACCTCATATGGA_Normoxia"',
#  '"ACCTCATCTATG_Normoxia"',
#  '"ACCTCCAGCTTA_Normoxia"',
#  '"ACCTCCAGTAGT_Normoxia"',
#  '"ACCTCCCCGATG_Normoxia"',
#  '"ACCTCCGACGCC_Normoxia"',
#  '"ACCTCCGCTCCG_Normoxia"',
#  '"ACCTCCTACCCG_Normoxia"',
#  '"ACCTCCTACCGC_Normoxia"',
#  '"ACCTCCTTCCCC_Normoxia"',
#  '"ACCTCGGCCACC_Normoxia"',
#  '"ACCTCGTGCGTG_Normoxia"',
#  '"ACCTCTACCCGT_Normoxia"',
#  '"ACCTGAAAACCG_Normoxia"',
#  '"ACCTGAAGACCT_Normoxia"',
#  '"ACCTGACGAAGA_Normoxia"',
#  '"ACCTGATGGTCT_Normoxia"',
#  '"ACCTGCACAAGC_Normoxia"',
#  '"ACCTGCCAGCAT_Normoxia"',
#  '"ACCTGGGCGTCC_Normoxia"',
#  '"ACCTTACACATT_Normoxia"',
#  '"ACCTTCACTGGG_Normoxia"',
#  '"ACCTTCCAGTGC_Normoxia"',
#  '"ACCTTCCCCACT_Normoxia"',
#  '"ACCTTCCCGTGA_Normoxia"',
#  '"ACCTTCGCGCAT_Normoxia"',
#  '"ACCTTCGGATTA_Normoxia"',
#  '"ACCTTCTCCTGG_Normoxia"',
#  '"ACCTTCTCCTGT_Normoxia"',
#  '"ACCTTGCTTAAG_Normoxia"',
#  '"ACCTTGGAGCTT_Normoxia"',
#  '"ACCTTGTACGTA_Normoxia"',
#  '"ACCTTGTTATCC_Normoxia"',
#  '"ACCTTTCGCACT_Normoxia"',
#  '"ACGAACAATAGA_Normoxia"',
#  '"ACGAACCCTCAC_Normoxia"',
#  '"ACGAACGCCACC_Normoxia"',
#  '"ACGAAGTTCCTT_Normoxia"',
#  '"ACGACAGATTAG_Normoxia"',
#  '"ACGACCACTCCC_Normoxia"',
#  '"ACGACCTGGTCT_Normoxia"',
#  '"ACGACGCAACTT_Normoxia"',
#  '"ACGACTTCCCTG_Normoxia"',
#  '"ACGAGAAAGACA_Normoxia"',
#  '"ACGAGACAGCGA_Normoxia"',
#  '"ACGAGAGCCTTT_Normoxia"',
#  '"ACGAGCTAAACA_Normoxia"',
#  '"ACGAGCTCGTTT_Normoxia"',
#  '"ACGAGGCCTCCC_Normoxia"',
#  '"ACGAGGGCAAAA_Normoxia"',
#  '"ACGAGGGCCTGG_Normoxia"',
#  '"ACGAGGTTACAC_Normoxia"',
#  '"ACGAGTCCTGGG_Normoxia"',
#  '"ACGAGTGTAAGC_Normoxia"',
#  '"ACGATATATTGG_Normoxia"',
#  '"ACGATCAGACGT_Normoxia"',
#  '"ACGATCGGCTGG_Normoxia"',
#  '"ACGATCGGTGTT_Normoxia"',
#  '"ACGATCGTGACC_Normoxia"',
#  '"ACGATGCAAAGC_Normoxia"',
#  '"ACGATTCATGTG_Normoxia"',
#  '"ACGCAACAGCTT_Normoxia"',
#  '"ACGCAACTTGCA_Normoxia"',
#  '"ACGCAAGCCCGG_Normoxia"',
#  '"ACGCAAGGAACT_Normoxia"',
#  '"ACGCAAGGCCGT_Normoxia"',
#  '"ACGCACACGATA_Normoxia"',
#  '"ACGCAGACTCCC_Normoxia"',
#  '"ACGCAGCCTAAT_Normoxia"',
#  '"ACGCAGGTTGGG_Normoxia"',
#  '"ACGCATAGTGAC_Normoxia"',
#  '"ACGCATCATTCG_Normoxia"',
#  '"ACGCATTCCCTC_Normoxia"',
#  '"ACGCCAACTTTG_Normoxia"',
#  '"ACGCCACCCGCG_Normoxia"',
#  '"ACGCCATATTAT_Normoxia"',
#  '"ACGCCCACAACG_Normoxia"',
#  '"ACGCCCCGAGGC_Normoxia"',
#  '"ACGCCCGCTGGA_Normoxia"',
#  '"ACGCCCTGACAC_Normoxia"',
#  '"ACGCCGCGCGCA_Normoxia"',
#  '"ACGCCGGCGAGT_Normoxia"',
#  '"ACGCCGGGGCCA_Normoxia"',
#  '"ACGCCGTCACCT_Normoxia"',
#  '"ACGCCGTCCCGT_Normoxia"',
#  '"ACGCCGTGGACT_Normoxia"',
#  '"ACGCCTAAAGCA_Normoxia"',
#  '"ACGCCTCCAAGT_Normoxia"',
#  '"ACGCCTCCAGTA_Normoxia"',
#  '"ACGCCTCTACCA_Normoxia"',
#  '"ACGCCTGATGCA_Normoxia"',
#  '"ACGCGAAACTGG_Normoxia"',
#  '"ACGCGACTAGTG_Normoxia"',
#  '"ACGCGAGACGCG_Normoxia"',
#  '"ACGCGCACTTGG_Normoxia"',
#  '"ACGCGCCACAGA_Normoxia"',
#  '"ACGCGCCCCCGT_Normoxia"',
#  '"ACGCGCGGACTC_Normoxia"',
#  '"ACGCGGGGAGAT_Normoxia"',
#  '"ACGCGTAGAAGC_Normoxia"',
#  '"ACGCGTAGGTCT_Normoxia"',
#  '"ACGCGTCGCCTG_Normoxia"',
#  '"ACGCGTTGAGCG_Normoxia"',
#  '"ACGCTAATCGCA_Normoxia"',
#  '"ACGCTAGATGTT_Normoxia"',
#  '"ACGCTAGCTGCT_Normoxia"',
#  '"ACGCTCCCCAGA_Normoxia"',
#  '"ACGCTCCGACAA_Normoxia"',
#  '"ACGCTCGCTGAC_Normoxia"',
#  '"ACGCTCGGGTCT_Normoxia"',
#  '"ACGCTGACTCCG_Normoxia"',
#  '"ACGCTGGCTCAA_Normoxia"',
#  '"ACGCTGGGTCTA_Normoxia"',
#  '"ACGCTGGTCACG_Normoxia"',
#  '"ACGCTGTCTCCA_Normoxia"',
#  '"ACGCTTAAACGG_Normoxia"',
#  '"ACGCTTACCAAG_Normoxia"',
#  '"ACGCTTGAACCT_Normoxia"',
#  '"ACGCTTTCCAGA_Normoxia"',
#  '"ACGCTTTTTAAC_Normoxia"',
#  '"ACGGAACCTGGG_Normoxia"',
#  '"ACGGAACTAGAT_Normoxia"',
#  '"ACGGAACTGTGT_Normoxia"',
#  '"ACGGACGGTGCT_Normoxia"',
#  '"ACGGACTAGGCC_Normoxia"',
#  '"ACGGACTTTTAT_Normoxia"',
#  '"ACGGAGCACCTG_Normoxia"',
#  '"ACGGAGCTATGG_Normoxia"',
#  '"ACGGATCCATCC_Normoxia"',
#  '"ACGGCATCTTCC_Normoxia"',
#  '"ACGGCATGACAA_Normoxia"',
#  '"ACGGCCCCCTGA_Normoxia"',
#  '"ACGGCCCCCTGC_Normoxia"',
#  '"ACGGCCCCCTGG_Normoxia"',
#  '"ACGGCCCCCTGT_Normoxia"',
#  '"ACGGCCCGATGT_Normoxia"',
#  '"ACGGCCGTTGTG_Normoxia"',
#  '"ACGGCGAACTTT_Normoxia"',
#  '"ACGGCGCGCTGA_Normoxia"',
#  '"ACGGCGGGCAGC_Normoxia"',
#  '"ACGGCTAACAAC_Normoxia"',
#  '"ACGGCTACTTAG_Normoxia"',
#  '"ACGGGAACCGAG_Normoxia"',
#  '"ACGGGCCAGATC_Normoxia"',
#  '"ACGGGCCAGTGA_Normoxia"',
#  '"ACGGGCCCTTGA_Normoxia"',
#  '"ACGGGCTCCCAC_Normoxia"',
#  '"ACGGGGACAATT_Normoxia"',
#  '"ACGGGGATTGAG_Normoxia"',
#  '"ACGGGGCTCGTA_Normoxia"',
#  '"ACGGGGGTCGCT_Normoxia"',
#  '"ACGGGTACTACT_Normoxia"',
#  '"ACGGGTAGAGAT_Normoxia"',
#  '"ACGGGTTGGCCG_Normoxia"',
#  '"ACGGTACAGGTG_Normoxia"',
#  '"ACGGTAGCATTC_Normoxia"',
#  '"ACGGTCAGATTC_Normoxia"',
#  '"ACGGTCGGCATG_Normoxia"',
#  '"ACGGTCGTGGGG_Normoxia"',
#  '"ACGGTGAGGGTG_Normoxia"',
#  '"ACGGTTACTAAT_Normoxia"',
#  '"ACGGTTCGGAGA_Normoxia"',
#  '"ACGGTTGCAACT_Normoxia"',
#  '"ACGTAACACTGC_Normoxia"',
#  '"ACGTAACGCCGG_Normoxia"',
#  '"ACGTAATAAAGG_Normoxia"',
#  '"ACGTACGGTCAC_Normoxia"',
#  '"ACGTATCCGAAG_Normoxia"',
#  '"ACGTATGGGGAA_Normoxia"',
#  '"ACGTCACTAGAG_Normoxia"',
#  '"ACGTCAGCGCTA_Normoxia"',
#  '"ACGTCCCCCTCG_Normoxia"',
#  '"ACGTCCCGGCTT_Normoxia"',
#  '"ACGTCCGGAACG_Normoxia"',
#  '"ACGTCCGGTCAG_Normoxia"',
#  '"ACGTCCTGGACC_Normoxia"',
#  '"ACGTCGAGTCGG_Normoxia"',
#  '"ACGTCGATTCTC_Normoxia"',
#  '"ACGTCGCTACCG_Normoxia"',
#  '"ACGTCGCTTTCA_Normoxia"',
#  '"ACGTCGGCCCCA_Normoxia"',
#  '"ACGTCGGCCCGA_Normoxia"',
#  '"ACGTCGGTTTCG_Normoxia"',
#  ...]

# %%
np.shape(df)
# Out:
# (3000, 21626)

# %%
df.head(5)
# Out:
#            "AAAAACCTATCG_Normoxia"  "AAAACAACCCTA_Normoxia"  \
# "MALAT1"                         1                        3
# "MT-RNR2"                        0                        0
# "NEAT1"                          0                        0
# "H1-5"                           0                        0
# "TFF1"                           4                        1
#
#            "AAAACACTCTCA_Normoxia"  "AAAACCAGGCAC_Normoxia"  \
# "MALAT1"                         3                        6
# "MT-RNR2"                        0                        2
# "NEAT1"                          0                        0
# "H1-5"                           0                        0
# "TFF1"                           1                        1
#
#            "AAAACCTAGCTC_Normoxia"  "AAAACCTCCGGG_Normoxia"  \
# "MALAT1"                         4                        5
# "MT-RNR2"                        0                        0
# "NEAT1"                          0                        2
# "H1-5"                           0                        2
# "TFF1"                           0                        0
#
#            "AAAACTCGTTGC_Normoxia"  "AAAAGAGCTCTC_Normoxia"  \
# "MALAT1"                         1                       13
# "MT-RNR2"                        2                        1
# "NEAT1"                          0                        1
# "H1-5"                           0                        0
# "TFF1"                           0                        2
#
#            "AAAAGCTAGGCG_Normoxia"  "AAAATCGCATTT_Normoxia"  ...  \
# "MALAT1"                         3                        3  ...
# "MT-RNR2"                        7                        0  ...
# "NEAT1"                          2                        0  ...
# "H1-5"                           0                        0  ...
# "TFF1"                           0                        1  ...
#
#            "TTTTACAGGATC_Hypoxia"  "TTTTACCACGTA_Hypoxia"  \
# "MALAT1"                        0                       2
# "MT-RNR2"                       0                       0
# "NEAT1"                         0                       0
# "H1-5"                          0                       1
# "TFF1"                          2                       3
#
#            "TTTTATGCTACG_Hypoxia"  "TTTTCCAGACGC_Hypoxia"  \
# "MALAT1"                        1                       0
# "MT-RNR2"                       0                       0
# "NEAT1"                         0                       0
# "H1-5"                          0                       0
# "TFF1"                          8                       0
#
#            "TTTTCGCGCTCG_Hypoxia"  "TTTTCGCGTAGA_Hypoxia"  \
# "MALAT1"                        1                       0
# "MT-RNR2"                       0                       0
# "NEAT1"                         0                       0
# "H1-5"                          1                       0
# "TFF1"                          0                       3
#
#            "TTTTCGTCCGCT_Hypoxia"  "TTTTCTCCGGCT_Hypoxia"  \
# "MALAT1"                        1                       0
# "MT-RNR2"                       0                       0
# "NEAT1"                         0                       0
# "H1-5"                          0                       1
# "TFF1"                          4                       2
#
#            "TTTTGTTCAAAG_Hypoxia"  "TTTTTTGTATGT_Hypoxia"
# "MALAT1"                        0                       4
# "MT-RNR2"                       0                       0
# "NEAT1"                         0                       0
# "H1-5"                          0                       0
# "TFF1"                          6                       0
#
# [5 rows x 21626 columns]

# %%
df.dtypes
# Out:
# "AAAAACCTATCG_Normoxia"    int64
# "AAAACAACCCTA_Normoxia"    int64
# "AAAACACTCTCA_Normoxia"    int64
# "AAAACCAGGCAC_Normoxia"    int64
# "AAAACCTAGCTC_Normoxia"    int64
#                            ...
# "TTTTCGCGTAGA_Hypoxia"     int64
# "TTTTCGTCCGCT_Hypoxia"     int64
# "TTTTCTCCGGCT_Hypoxia"     int64
# "TTTTGTTCAAAG_Hypoxia"     int64
# "TTTTTTGTATGT_Hypoxia"     int64
# Length: 21626, dtype: object

# %%
X= df.to_numpy()
X
np.shape(X)
# Out:
# (3000, 21626)

# %%
print(df.isnull().sum())
# Out:
# "AAAAACCTATCG_Normoxia"    0
# "AAAACAACCCTA_Normoxia"    0
# "AAAACACTCTCA_Normoxia"    0
# "AAAACCAGGCAC_Normoxia"    0
# "AAAACCTAGCTC_Normoxia"    0
#                           ..
# "TTTTCGCGTAGA_Hypoxia"     0
# "TTTTCGTCCGCT_Hypoxia"     0
# "TTTTCTCCGGCT_Hypoxia"     0
# "TTTTGTTCAAAG_Hypoxia"     0
# "TTTTTTGTATGT_Hypoxia"     0
# Length: 21626, dtype: int64

# %%
df = df.dropna()  # Dropping the missing values.
df.count()
# Out:
# "AAAAACCTATCG_Normoxia"    3000
# "AAAACAACCCTA_Normoxia"    3000
# "AAAACACTCTCA_Normoxia"    3000
# "AAAACCAGGCAC_Normoxia"    3000
# "AAAACCTAGCTC_Normoxia"    3000
#                            ...
# "TTTTCGCGTAGA_Hypoxia"     3000
# "TTTTCGTCCGCT_Hypoxia"     3000
# "TTTTCTCCGGCT_Hypoxia"     3000
# "TTTTGTTCAAAG_Hypoxia"     3000
# "TTTTTTGTATGT_Hypoxia"     3000
# Length: 21626, dtype: int64

# %%
print(df.isnull().sum())   # After dropping the values
# Out:
# "AAAAACCTATCG_Normoxia"    0
# "AAAACAACCCTA_Normoxia"    0
# "AAAACACTCTCA_Normoxia"    0
# "AAAACCAGGCAC_Normoxia"    0
# "AAAACCTAGCTC_Normoxia"    0
#                           ..
# "TTTTCGCGTAGA_Hypoxia"     0
# "TTTTCGTCCGCT_Hypoxia"     0
# "TTTTCTCCGGCT_Hypoxia"     0
# "TTTTGTTCAAAG_Hypoxia"     0
# "TTTTTTGTATGT_Hypoxia"     0
# Length: 21626, dtype: int64

# %%
df.iloc[ 1:5 , 1:5 ]
# Out:
#            "AAAACAACCCTA_Normoxia"  "AAAACACTCTCA_Normoxia"  \
# "MT-RNR2"                        0                        0
# "NEAT1"                          0                        0
# "H1-5"                           0                        0
# "TFF1"                           1                        1
#
#            "AAAACCAGGCAC_Normoxia"  "AAAACCTAGCTC_Normoxia"
# "MT-RNR2"                        2                        0
# "NEAT1"                          0                        0
# "H1-5"                           0                        0
# "TFF1"                           1                        0

# %%
df.describe()
# Out:
#        "AAAAACCTATCG_Normoxia"  "AAAACAACCCTA_Normoxia"  \
# count              3000.000000              3000.000000
# mean                  0.034000                 0.030333
# std                   0.277254                 0.220823
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                   4.000000                 4.000000
#
#        "AAAACACTCTCA_Normoxia"  "AAAACCAGGCAC_Normoxia"  \
# count              3000.000000              3000.000000
# mean                  0.027000                 0.032333
# std                   0.195662                 0.233751
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                   5.000000                 6.000000
#
#        "AAAACCTAGCTC_Normoxia"  "AAAACCTCCGGG_Normoxia"  \
# count              3000.000000              3000.000000
# mean                  0.045333                 0.047333
# std                   0.246235                 0.299649
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                   4.000000                 8.000000
#
#        "AAAACTCGTTGC_Normoxia"  "AAAAGAGCTCTC_Normoxia"  \
# count              3000.000000              3000.000000
# mean                  0.030000                 0.027333
# std                   0.204403                 0.292030
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                   6.000000                13.000000
#
#        "AAAAGCTAGGCG_Normoxia"  "AAAATCGCATTT_Normoxia"  ...  \
# count              3000.000000              3000.000000  ...
# mean                  0.032000                 0.027333  ...
# std                   0.281074                 0.237918  ...
# min                   0.000000                 0.000000  ...
# 25%                   0.000000                 0.000000  ...
# 50%                   0.000000                 0.000000  ...
# 75%                   0.000000                 0.000000  ...
# max                   7.000000                 6.000000  ...
#
#        "TTTTACAGGATC_Hypoxia"  "TTTTACCACGTA_Hypoxia"  "TTTTATGCTACG_Hypoxia"  \
# count             3000.000000             3000.000000             3000.000000
# mean                 0.052333                0.043667                0.033667
# std                  0.364654                0.244499                0.340449
# min                  0.000000                0.000000                0.000000
# 25%                  0.000000                0.000000                0.000000
# 50%                  0.000000                0.000000                0.000000
# 75%                  0.000000                0.000000                0.000000
# max                  7.000000                4.000000               10.000000
#
#        "TTTTCCAGACGC_Hypoxia"  "TTTTCGCGCTCG_Hypoxia"  "TTTTCGCGTAGA_Hypoxia"  \
# count             3000.000000             3000.000000             3000.000000
# mean                 0.033000                0.025333                0.037000
# std                  0.302117                0.208261                0.286924
# min                  0.000000                0.000000                0.000000
# 25%                  0.000000                0.000000                0.000000
# 50%                  0.000000                0.000000                0.000000
# 75%                  0.000000                0.000000                0.000000
# max                  8.000000                6.000000                7.000000
#
#        "TTTTCGTCCGCT_Hypoxia"  "TTTTCTCCGGCT_Hypoxia"  "TTTTGTTCAAAG_Hypoxia"  \
# count             3000.000000             3000.000000             3000.000000
# mean                 0.046333                0.055667                0.038000
# std                  0.301469                0.358623                0.240642
# min                  0.000000                0.000000                0.000000
# 25%                  0.000000                0.000000                0.000000
# 50%                  0.000000                0.000000                0.000000
# 75%                  0.000000                0.000000                0.000000
# max                  7.000000                9.000000                6.000000
#
#        "TTTTTTGTATGT_Hypoxia"
# count             3000.000000
# mean                 0.033000
# std                  0.244808
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                  0.000000
# max                  6.000000
#
# [8 rows x 21626 columns]

# %%
cnames = list(df.columns)
cnames[1]
sns.boxplot(x=df[cnames[1]])
# Out:
# <Axes: xlabel='"AAAACAACCCTA_Normoxia"'>

# %%
sns.violinplot(x=df[cnames[1]])
# Out:
# <Axes: xlabel='"AAAACAACCCTA_Normoxia"'>

# %%
df_small = df.iloc[:, :50]
np.shape(df_small)
plt.figure(figsize=(16, 4))
plot = sns.violinplot(data=df_small, palette="Set3", cut=0)
plt.setp(plot.get_xticklabels(), rotation=90)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# "AAAAACCTATCG_Normoxia"    0.0
# "AAAACAACCCTA_Normoxia"    0.0
# "AAAACACTCTCA_Normoxia"    0.0
# "AAAACCAGGCAC_Normoxia"    0.0
# "AAAACCTAGCTC_Normoxia"    0.0
#                           ...
# "TTTTCGCGTAGA_Hypoxia"     0.0
# "TTTTCGTCCGCT_Hypoxia"     0.0
# "TTTTCTCCGGCT_Hypoxia"     0.0
# "TTTTGTTCAAAG_Hypoxia"     0.0
# "TTTTTTGTATGT_Hypoxia"     0.0
# Length: 21626, dtype: float64

# %%
df_noOut = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df_noOut.shape
df_noOut.head(3)
# Out:
# Empty DataFrame
# Columns: ["AAAAACCTATCG_Normoxia", "AAAACAACCCTA_Normoxia", "AAAACACTCTCA_Normoxia", "AAAACCAGGCAC_Normoxia", "AAAACCTAGCTC_Normoxia", "AAAACCTCCGGG_Normoxia", "AAAACTCGTTGC_Normoxia", "AAAAGAGCTCTC_Normoxia", "AAAAGCTAGGCG_Normoxia", "AAAATCGCATTT_Normoxia", "AAAATCTACATA_Normoxia", "AAAATGGCTCTC_Normoxia", "AAAATGGGCCGG_Normoxia", "AAACAAACTCAA_Normoxia", "AAACAACGAATT_Normoxia", "AAACAATGAGGT_Normoxia", "AAACACGCCGCG_Normoxia", "AAACAGCACGAC_Normoxia", "AAACATACCCGT_Normoxia", "AAACATGGATCC_Normoxia", "AAACATTAGAAT_Normoxia", "AAACCAACCGGT_Normoxia", "AAACCAGCCTGG_Normoxia", "AAACCAGGCTCT_Normoxia", "AAACCAGGGCAC_Normoxia", "AAACCCGATTTC_Normoxia", "AAACCGACGTCG_Normoxia", "AAACCGCTGCAT_Normoxia", "AAACCGTCCCGC_Normoxia", "AAACCGTTAGCC_Normoxia", "AAACCGTTGGGG_Normoxia", "AAACCGTTTCTT_Normoxia", "AAACCTAGGAGA_Normoxia", "AAACCTATTGTC_Normoxia", "AAACCTCCACGA_Normoxia", "AAACCTGAGGGA_Normoxia", "AAACGCACGGAC_Normoxia", "AAACGCTGGCTT_Normoxia", "AAACGGAGTGAA_Normoxia", "AAACGGCCCCCT_Normoxia", "AAACGGCCTAGG_Normoxia", "AAACGGCGGGTG_Normoxia", "AAACTACCTAAC_Normoxia", "AAACTCACCTGA_Normoxia", "AAACTCCACAAG_Normoxia", "AAACTCGGGGTG_Normoxia", "AAACTGGGCCGT_Normoxia", "AAACTGTCTCAA_Normoxia", "AAACTTGCGGGT_Normoxia", "AAACTTTCCCGT_Normoxia", "AAAGAAGAGCCT_Normoxia", "AAAGACAACTCC_Normoxia", "AAAGACCGGGTG_Normoxia", "AAAGACCGTCTG_Normoxia", "AAAGCACTGTTA_Normoxia", "AAAGCAGCGATC_Normoxia", "AAAGCCCCATCT_Normoxia", "AAAGCCTCTATG_Normoxia", "AAAGCGTAACCG_Normoxia", "AAAGCTAACATG_Normoxia", "AAAGCTCAGACT_Normoxia", "AAAGGAAGACCT_Normoxia", "AAAGGACCAGAT_Normoxia", "AAAGGACGCAAA_Normoxia", "AAAGGCAAGGAA_Normoxia", "AAAGGCAGGCCT_Normoxia", "AAAGGCCGCATG_Normoxia", "AAAGGCGAGGCG_Normoxia", "AAAGGCGCGGTG_Normoxia", "AAAGGGCCCCAT_Normoxia", "AAAGGTATGGTG_Normoxia", "AAAGTTAACTCG_Normoxia", "AAATAGGTCCCG_Normoxia", "AAATCACATGGG_Normoxia", "AAATCACCGCCA_Normoxia", "AAATCCAATTTA_Normoxia", "AAATCCGACGCC_Normoxia", "AAATCCTTCTTG_Normoxia", "AAATCGCACTTC_Normoxia", "AAATCGCAGTCA_Normoxia", "AAATCGCGCTAT_Normoxia", "AAATGAAAACCT_Normoxia", "AAATGACCTTAG_Normoxia", "AAATGACGCTTG_Normoxia", "AAATGACTCAGC_Normoxia", "AAATGCGTGGTG_Normoxia", "AAATGCTGTCCG_Normoxia", "AAATGGTCTGCG_Normoxia", "AAATGTACAAGC_Normoxia", "AAATGTCCCGCA_Normoxia", "AAATTACGCCCC_Normoxia", "AAATTCGTGCGG_Normoxia", "AACAAAGCAACA_Normoxia", "AACAAAGGGTTC_Normoxia", "AACAAATCGTAT_Normoxia", "AACAACCTACGA_Normoxia", "AACAAGCCCTGG_Normoxia", "AACAAGTCCAAT_Normoxia", "AACAATAGCGTT_Normoxia", "AACAATCCCACC_Normoxia", ...]
# Index: []
#
# [0 rows x 21626 columns]

# %%
sns.boxplot(x=df_noOut[cnames[1]])
# Out:
# <Axes: >

# %%
df_noOut_small = df.iloc[:, :50]
np.shape(df_noOut_small)
plt.figure(figsize=(16,4))
plot=sns.violinplot(data=df_noOut_small,palette="Set3",cut=0)
plt.setp(plot.get_xticklabels(), rotation=90)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
from scipy.stats import kurtosis, skew

colN = np.shape(df)[1]
colN
df_skew_cells = []
for i in range(colN):
    v_df = df[cnames[i]]
    df_skew_cells += [skew(v_df)]
#  df_skew_cells += [df[cnames[i]].skew()]
df_skew_cells
sns.histplot(df_skew_cells, bins=100)
plt.xlabel('Skewness of single cells expression profiles - original df')
# Out:
# Text(0.5, 0, 'Skewness of single cells expression profiles - original df')

# %%
df_kurt_cells = []
for i in range(colN):
    v_df = df[cnames[i]]
    df_kurt_cells += [kurtosis(v_df)]
#   df_kurt_cells += [df[cnames[i]].kurt()]
df_kurt_cells
sns.histplot(df_kurt_cells, bins=100)
plt.xlabel('Kurtosis of single cells expression profiles - original df')
# Out:
# Text(0.5, 0, 'Kurtosis of single cells expression profiles - original df')

# %%
xnorm = np.random.normal(0, 2, 10000000)   # create random values based on a normal distribution
xnorm

print( "Excess kurtosis of normal distribution: ",  kurtosis(xnorm) )
print( "Skewness of normal distribution: ", skew(xnorm) )
# Out:
# Excess kurtosis of normal distribution:  -0.000307159921277389
# Skewness of normal distribution:  0.00043913353354029145

# %%
df11_log2 = np.log2(df[cnames[1]] + 1)
sns.boxplot(x=df11_log2)
# Out:
# <Axes: xlabel='"AAAACAACCCTA_Normoxia"'>

# %%
sns.violinplot(x=df11_log2)
# Out:
# <Axes: xlabel='"AAAACAACCCTA_Normoxia"'>

# %%
display(df11_log2.describe().round(2))
# Out:
# count    3000.00
# mean        0.03
# std         0.18
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max         2.32
# Name: "AAAACAACCCTA_Normoxia", dtype: float64

# %%
df1 = df + 1
df1_log2 = df1.apply(np.log2)
# I'm selecting part of the data as the plots would otherwise take too long to generate
df1_log2_small = df1_log2.iloc[:, :50]
np.shape(df1_log2_small)
plt.figure(figsize=(16,4))
plot=sns.violinplot(data=df1_log2_small,palette="Set3",cut=0)
plt.setp(plot.get_xticklabels(), rotation=90)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
df1_log2_skew_cells = []
for i in range(colN):
    v_df = df1_log2[cnames[i]]
    df1_log2_skew_cells += [skew(v_df)]
df1_log2_skew_cells
sns.histplot(df1_log2_skew_cells, bins=100)
plt.xlabel('Skewness of single cells expression profiles - log2 df')
# Out:
# Text(0.5, 0, 'Skewness of single cells expression profiles - log2 df')

# %%
df1_log2_kurt_cells = []
for i in range(colN) :
     v_df = df1_log2[cnames[i]]
     df1_log2_kurt_cells += [kurtosis(v_df)]
sns.histplot(df1_log2_kurt_cells,bins=100)
plt.xlabel('Kurtosis of single cells expression profiles - log2 df')
# Out:
# Text(0.5, 0, 'Kurtosis of single cells expression profiles - log2 df')

# %%
df = df1_log2
df_small = df.iloc[:, 10:30]  #just selecting part of the samples so run time not too long
sns.displot(data=df_small, palette="Set3", kind="kde", bw_adjust=2)

# %%
duplicate_rows_df = df[df.duplicated(keep=False)]
print("number of duplicate rows: ", duplicate_rows_df.shape)
print("number of duplicate rows: ", duplicate_rows_df)
# Out:
# number of duplicate rows:  (0, 21626)
# number of duplicate rows:  Empty DataFrame
# Columns: ["AAAAACCTATCG_Normoxia", "AAAACAACCCTA_Normoxia", "AAAACACTCTCA_Normoxia", "AAAACCAGGCAC_Normoxia", "AAAACCTAGCTC_Normoxia", "AAAACCTCCGGG_Normoxia", "AAAACTCGTTGC_Normoxia", "AAAAGAGCTCTC_Normoxia", "AAAAGCTAGGCG_Normoxia", "AAAATCGCATTT_Normoxia", "AAAATCTACATA_Normoxia", "AAAATGGCTCTC_Normoxia", "AAAATGGGCCGG_Normoxia", "AAACAAACTCAA_Normoxia", "AAACAACGAATT_Normoxia", "AAACAATGAGGT_Normoxia", "AAACACGCCGCG_Normoxia", "AAACAGCACGAC_Normoxia", "AAACATACCCGT_Normoxia", "AAACATGGATCC_Normoxia", "AAACATTAGAAT_Normoxia", "AAACCAACCGGT_Normoxia", "AAACCAGCCTGG_Normoxia", "AAACCAGGCTCT_Normoxia", "AAACCAGGGCAC_Normoxia", "AAACCCGATTTC_Normoxia", "AAACCGACGTCG_Normoxia", "AAACCGCTGCAT_Normoxia", "AAACCGTCCCGC_Normoxia", "AAACCGTTAGCC_Normoxia", "AAACCGTTGGGG_Normoxia", "AAACCGTTTCTT_Normoxia", "AAACCTAGGAGA_Normoxia", "AAACCTATTGTC_Normoxia", "AAACCTCCACGA_Normoxia", "AAACCTGAGGGA_Normoxia", "AAACGCACGGAC_Normoxia", "AAACGCTGGCTT_Normoxia", "AAACGGAGTGAA_Normoxia", "AAACGGCCCCCT_Normoxia", "AAACGGCCTAGG_Normoxia", "AAACGGCGGGTG_Normoxia", "AAACTACCTAAC_Normoxia", "AAACTCACCTGA_Normoxia", "AAACTCCACAAG_Normoxia", "AAACTCGGGGTG_Normoxia", "AAACTGGGCCGT_Normoxia", "AAACTGTCTCAA_Normoxia", "AAACTTGCGGGT_Normoxia", "AAACTTTCCCGT_Normoxia", "AAAGAAGAGCCT_Normoxia", "AAAGACAACTCC_Normoxia", "AAAGACCGGGTG_Normoxia", "AAAGACCGTCTG_Normoxia", "AAAGCACTGTTA_Normoxia", "AAAGCAGCGATC_Normoxia", "AAAGCCCCATCT_Normoxia", "AAAGCCTCTATG_Normoxia", "AAAGCGTAACCG_Normoxia", "AAAGCTAACATG_Normoxia", "AAAGCTCAGACT_Normoxia", "AAAGGAAGACCT_Normoxia", "AAAGGACCAGAT_Normoxia", "AAAGGACGCAAA_Normoxia", "AAAGGCAAGGAA_Normoxia", "AAAGGCAGGCCT_Normoxia", "AAAGGCCGCATG_Normoxia", "AAAGGCGAGGCG_Normoxia", "AAAGGCGCGGTG_Normoxia", "AAAGGGCCCCAT_Normoxia", "AAAGGTATGGTG_Normoxia", "AAAGTTAACTCG_Normoxia", "AAATAGGTCCCG_Normoxia", "AAATCACATGGG_Normoxia", "AAATCACCGCCA_Normoxia", "AAATCCAATTTA_Normoxia", "AAATCCGACGCC_Normoxia", "AAATCCTTCTTG_Normoxia", "AAATCGCACTTC_Normoxia", "AAATCGCAGTCA_Normoxia", "AAATCGCGCTAT_Normoxia", "AAATGAAAACCT_Normoxia", "AAATGACCTTAG_Normoxia", "AAATGACGCTTG_Normoxia", "AAATGACTCAGC_Normoxia", "AAATGCGTGGTG_Normoxia", "AAATGCTGTCCG_Normoxia", "AAATGGTCTGCG_Normoxia", "AAATGTACAAGC_Normoxia", "AAATGTCCCGCA_Normoxia", "AAATTACGCCCC_Normoxia", "AAATTCGTGCGG_Normoxia", "AACAAAGCAACA_Normoxia", "AACAAAGGGTTC_Normoxia", "AACAAATCGTAT_Normoxia", "AACAACCTACGA_Normoxia", "AACAAGCCCTGG_Normoxia", "AACAAGTCCAAT_Normoxia", "AACAATAGCGTT_Normoxia", "AACAATCCCACC_Normoxia", ...]
# Index: []
#
# [0 rows x 21626 columns]

# %%
duplicate_rows_df_t = duplicate_rows_df.T
duplicate_rows_df_t
c_dupl = duplicate_rows_df_t.corr()
c_dupl
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
duplicate_rows_df_t.describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 duplicate_rows_df_t.describe()
#
# File ~\PycharmProjects\AI-Lab\venv\lib\site-packages\pandas\core\generic.py:11976, in NDFrame.describe(self, percentiles, include, exclude)
#   11734 @final
#   11735 def describe(
#   11736     self,
#    (...)
#   11739     exclude=None,
#   11740 ) -> Self:
#   11741     """
#   11742     Generate descriptive statistics.
#   11743
#    (...)
#   11974     max            NaN      3.0
#   11975     """
# > 11976     return describe_ndframe(
#   11977         obj=self,
#   11978         include=include,
#   11979         exclude=exclude,
#   11980         percentiles=percentiles,
#   11981     ).__finalize__(self, method="describe")
#
# File ~\PycharmProjects\AI-Lab\venv\lib\site-packages\pandas\core\methods\describe.py:91, in describe_ndframe(obj, include, exclude, percentiles)
#      87     describer = SeriesDescriber(
#      88         obj=cast("Series", obj),
#      89     )
#      90 else:
# ---> 91     describer = DataFrameDescriber(
#      92         obj=cast("DataFrame", obj),
#      93         include=include,
#      94         exclude=exclude,
#      95     )
#      97 result = describer.describe(percentiles=percentiles)
#      98 return cast(NDFrameT, result)
#
# File ~\PycharmProjects\AI-Lab\venv\lib\site-packages\pandas\core\methods\describe.py:162, in DataFrameDescriber.__init__(self, obj, include, exclude)
#     159 self.exclude = exclude
#     161 if obj.ndim == 2 and obj.columns.size == 0:
# --> 162     raise ValueError("Cannot describe a DataFrame without columns")
#     164 super().__init__(obj)
#
# ValueError: Cannot describe a DataFrame without columns

# %%
df_noDup = df.drop_duplicates()
df_noDup.count()

# %%
df = df_noDup

# %%
plt.figure(figsize=(10, 5))
#df_small = df.iloc[:, :50]
#c= df_small.corr()
c = df.corr()
midpoint = (c.values.max() - c.values.min()) / 2 + c.values.min()
#sns.heatmap(c,cmap='coolwarm',annot=True, center=midpoint )
sns.heatmap(c, cmap='coolwarm', center=0)
print("Number of cells included: ", np.shape(c))
print("Average correlation of expression profiles between cells: ", midpoint)
print("Min. correlation of expression profiles between cells: ", c.values.min())

# %%
np.shape(c)
type(c)
c.head(3)
c_small=c.iloc[:,:3]
sns.histplot(c_small,bins=100)
plt.ylabel('Frequency')
plt.xlabel('Correlation between cells expression profiles')
