# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt             #visualisation
import seaborn as sns   #visualisation
# %matplotlib inline
sns.set(color_codes=True)

# %%
df = pd.read_csv("C:\\Users\\camer\\Desktop\\class stuff\\Semester 4\\ai lab\\DropSeq\\HCC1806_Filtered_Normalised_3000_Data_train.txt", delimiter="\ ", engine='python', index_col=0)
print("Dataframe dimensions:", np.shape(df))
print("First column: ", df.iloc[:, 0])
# Out:
# Dataframe dimensions: (3000, 14682)
# First column:  "H1-5"       2
# "MALAT1"     3
# "MT-RNR2"    0
# "ARVCF"      0
# "BCYRN1"     0
#             ..
# "SCCPDH"     0
# "NTAN1"      0
# "CLIP2"      0
# "DUSP23"     0
# "ZNF682"     0
# Name: "AAAAAACCCGGC_Normoxia", Length: 3000, dtype: int64

# %%
#do the same analysis
df.shape
# Out:
# (3000, 14682)

# %%
list(df.columns)
# Out:
# ['"AAAAAACCCGGC_Normoxia"',
#  '"AAAACCGGATGC_Normoxia"',
#  '"AAAACGAGCTAG_Normoxia"',
#  '"AAAACTTCCCCG_Normoxia"',
#  '"AAAAGCCTACCC_Normoxia"',
#  '"AAACACAAATCT_Normoxia"',
#  '"AAACCAAGCCCA_Normoxia"',
#  '"AAACCATGCACT_Normoxia"',
#  '"AAACCTCCGGCT_Normoxia"',
#  '"AAACGCCGGTCC_Normoxia"',
#  '"AAACGCCGTTCC_Normoxia"',
#  '"AAACGGACGCTC_Normoxia"',
#  '"AAACGTAGAGCG_Normoxia"',
#  '"AAACGTTCACTG_Normoxia"',
#  '"AAACTCATAAAT_Normoxia"',
#  '"AAAGACGGTACC_Normoxia"',
#  '"AAAGAGTGTACG_Normoxia"',
#  '"AAAGCTGACGAA_Normoxia"',
#  '"AAAGGCGGCAGG_Normoxia"',
#  '"AAAGGCGTTCGA_Normoxia"',
#  '"AAAGTCTGGGTC_Normoxia"',
#  '"AAAGTGGCACCC_Normoxia"',
#  '"AAAGTGGTTCGT_Normoxia"',
#  '"AAAGTGTTGTTC_Normoxia"',
#  '"AAATAGCCAGTT_Normoxia"',
#  '"AAATCCCATATA_Normoxia"',
#  '"AAATCGTGGTTG_Normoxia"',
#  '"AAATCTGGCGAC_Normoxia"',
#  '"AAATGACAGTCC_Normoxia"',
#  '"AAATGCAAAGGC_Normoxia"',
#  '"AAATGCCGGCTT_Normoxia"',
#  '"AAATGTTACGAG_Normoxia"',
#  '"AAATTTTACCCG_Normoxia"',
#  '"AAATTTTTAACT_Normoxia"',
#  '"AACAATTGAAGA_Normoxia"',
#  '"AACACACGCCCG_Normoxia"',
#  '"AACACCCCCCTC_Normoxia"',
#  '"AACACCCTCCGA_Normoxia"',
#  '"AACACCGGCTGC_Normoxia"',
#  '"AACACTAGCCGG_Normoxia"',
#  '"AACACTAGGATC_Normoxia"',
#  '"AACAGAGCAGCC_Normoxia"',
#  '"AACAGATAGAAG_Normoxia"',
#  '"AACATAATCAGT_Normoxia"',
#  '"AACATACAATGG_Normoxia"',
#  '"AACATATGGACT_Normoxia"',
#  '"AACCAAGGCTCC_Normoxia"',
#  '"AACCACCTGGTG_Normoxia"',
#  '"AACCAGGGTTGT_Normoxia"',
#  '"AACCAGTCCAAC_Normoxia"',
#  '"AACCCACAACCT_Normoxia"',
#  '"AACCCGCAATTT_Normoxia"',
#  '"AACCCGCCATTA_Normoxia"',
#  '"AACCCGGAGCGC_Normoxia"',
#  '"AACCCGTACATC_Normoxia"',
#  '"AACCCGTTCGCG_Normoxia"',
#  '"AACCCTCCCGAT_Normoxia"',
#  '"AACCCTGCCGTG_Normoxia"',
#  '"AACCGAGGCCAC_Normoxia"',
#  '"AACCGATGAGTT_Normoxia"',
#  '"AACCGCGAGCCC_Normoxia"',
#  '"AACCGCGAGCCT_Normoxia"',
#  '"AACCGCGAGCTC_Normoxia"',
#  '"AACCGTCTCTTA_Normoxia"',
#  '"AACCTAATACTT_Normoxia"',
#  '"AACCTACGAGAG_Normoxia"',
#  '"AACCTACTAGCG_Normoxia"',
#  '"AACCTCACCGCT_Normoxia"',
#  '"AACCTCCCGAGT_Normoxia"',
#  '"AACCTCCGGCTC_Normoxia"',
#  '"AACCTCCGGCTT_Normoxia"',
#  '"AACCTGCTTACG_Normoxia"',
#  '"AACCTGGGTGTT_Normoxia"',
#  '"AACGACCACCGG_Normoxia"',
#  '"AACGACCGCGGG_Normoxia"',
#  '"AACGACTACCCT_Normoxia"',
#  '"AACGCAGTTTAT_Normoxia"',
#  '"AACGCCCGCGGG_Normoxia"',
#  '"AACGCCGCCAGT_Normoxia"',
#  '"AACGCCGCGGGC_Normoxia"',
#  '"AACGCCGCGGGT_Normoxia"',
#  '"AACGCCTGTCAC_Normoxia"',
#  '"AACGCGTGCTAT_Normoxia"',
#  '"AACGCTCCGGAA_Normoxia"',
#  '"AACGGACCCCTG_Normoxia"',
#  '"AACGGACGGGAT_Normoxia"',
#  '"AACGGAGCATTT_Normoxia"',
#  '"AACGGCACCCTG_Normoxia"',
#  '"AACGGCCACCTG_Normoxia"',
#  '"AACGGCCCCAAC_Normoxia"',
#  '"AACGGCCCCAAT_Normoxia"',
#  '"AACGGCCCCATG_Normoxia"',
#  '"AACGGCCCCCAC_Normoxia"',
#  '"AACGGCCCCCCC_Normoxia"',
#  '"AACGGCCCCCCT_Normoxia"',
#  '"AACGGCCCCCGC_Normoxia"',
#  '"AACGGCCCCCGG_Normoxia"',
#  '"AACGGCCCCCGT_Normoxia"',
#  '"AACGGCCCCCTA_Normoxia"',
#  '"AACGGCCCCCTT_Normoxia"',
#  '"AACGGCCCCGGG_Normoxia"',
#  '"AACGGCCCGTCC_Normoxia"',
#  '"AACGGCCTAGGT_Normoxia"',
#  '"AACGGCTCTAAC_Normoxia"',
#  '"AACGGCTTCGGT_Normoxia"',
#  '"AACGGGAGGCAG_Normoxia"',
#  '"AACGGTACACCG_Normoxia"',
#  '"AACGGTCCCGCA_Normoxia"',
#  '"AACGGTCGGCAG_Normoxia"',
#  '"AACGTAAGTAGT_Normoxia"',
#  '"AACGTAGACTGG_Normoxia"',
#  '"AACGTCCCCCGC_Normoxia"',
#  '"AACGTGCCCGTG_Normoxia"',
#  '"AACGTGTCAGAC_Normoxia"',
#  '"AACGTTGGGCCT_Normoxia"',
#  '"AACGTTTAAGCT_Normoxia"',
#  '"AACTAGAGTGCT_Normoxia"',
#  '"AACTCACAAAAT_Normoxia"',
#  '"AACTCACAAATG_Normoxia"',
#  '"AACTCACTATCA_Normoxia"',
#  '"AACTCCCCTGCA_Normoxia"',
#  '"AACTCCCGCCCC_Normoxia"',
#  '"AACTCCCTGCAG_Normoxia"',
#  '"AACTCCCTTGCA_Normoxia"',
#  '"AACTCGCCTGTG_Normoxia"',
#  '"AACTGCGTGCTT_Normoxia"',
#  '"AACTGCGTGTCG_Normoxia"',
#  '"AACTGGGAACCT_Normoxia"',
#  '"AACTGGGGAACC_Normoxia"',
#  '"AACTGTAAAGCG_Normoxia"',
#  '"AACTGTGCCTTT_Normoxia"',
#  '"AACTTACCTCTC_Normoxia"',
#  '"AACTTCCAAGTG_Normoxia"',
#  '"AACTTCTCCCGC_Normoxia"',
#  '"AAGAACCGTCGT_Normoxia"',
#  '"AAGAATTTCCCG_Normoxia"',
#  '"AAGACACCCCCC_Normoxia"',
#  '"AAGACAGCTTTG_Normoxia"',
#  '"AAGACCGCGTGC_Normoxia"',
#  '"AAGAGCGCCGGT_Normoxia"',
#  '"AAGATACGGACC_Normoxia"',
#  '"AAGATAGTCCAA_Normoxia"',
#  '"AAGATCCCTTAG_Normoxia"',
#  '"AAGATGAGCTAT_Normoxia"',
#  '"AAGCACGACCAG_Normoxia"',
#  '"AAGCAGATATTC_Normoxia"',
#  '"AAGCAGGAGGTT_Normoxia"',
#  '"AAGCCCTCCATC_Normoxia"',
#  '"AAGCCGGTAGCA_Normoxia"',
#  '"AAGCCGGTTAGC_Normoxia"',
#  '"AAGCCGTATGTG_Normoxia"',
#  '"AAGCCTCGTCTT_Normoxia"',
#  '"AAGCGCATTGGC_Normoxia"',
#  '"AAGCTGACACTC_Normoxia"',
#  '"AAGCTGCGCGAC_Normoxia"',
#  '"AAGCTGCTGAAA_Normoxia"',
#  '"AAGGAGTAAAGA_Normoxia"',
#  '"AAGGAGTTCTCC_Normoxia"',
#  '"AAGGATCATGGG_Normoxia"',
#  '"AAGGCGCGGCTC_Normoxia"',
#  '"AAGGCGGCAGGG_Normoxia"',
#  '"AAGGCTTAATGA_Normoxia"',
#  '"AAGGGCGTCCCT_Normoxia"',
#  '"AAGGGTTTCCCA_Normoxia"',
#  '"AAGGTACTCGCC_Normoxia"',
#  '"AAGGTATTTGGC_Normoxia"',
#  '"AAGTCCACACGG_Normoxia"',
#  '"AAGTCCACCCAT_Normoxia"',
#  '"AAGTCCATCCCG_Normoxia"',
#  '"AAGTGCCTCCGG_Normoxia"',
#  '"AAGTGCCTCGGG_Normoxia"',
#  '"AAGTGCCTTCGG_Normoxia"',
#  '"AAGTGGTGCGTA_Normoxia"',
#  '"AAGTGTAAGGTT_Normoxia"',
#  '"AAGTTGCATGCA_Normoxia"',
#  '"AAGTTTCCCAGT_Normoxia"',
#  '"AATAGCCGCCAA_Normoxia"',
#  '"AATAGTGTGACC_Normoxia"',
#  '"AATATCTCGCGT_Normoxia"',
#  '"AATCACAATCCG_Normoxia"',
#  '"AATCACGCGTGC_Normoxia"',
#  '"AATCACGGTTGG_Normoxia"',
#  '"AATCCCCACTTC_Normoxia"',
#  '"AATCCCGCATTA_Normoxia"',
#  '"AATCCGGTGTCA_Normoxia"',
#  '"AATCCGTCTCCA_Normoxia"',
#  '"AATCGAACAGAA_Normoxia"',
#  '"AATCGACGCCCG_Normoxia"',
#  '"AATCGCCCATGT_Normoxia"',
#  '"AATCGGGCCTAG_Normoxia"',
#  '"AATCGGGGCGGA_Normoxia"',
#  '"AATCGTCTCCGT_Normoxia"',
#  '"AATCTACTCATC_Normoxia"',
#  '"AATCTAGTATCC_Normoxia"',
#  '"AATCTCATCGGC_Normoxia"',
#  '"AATGACGTTATC_Normoxia"',
#  '"AATGAGCCTCCG_Normoxia"',
#  '"AATGAGGGTTTA_Normoxia"',
#  '"AATGAGGTATCT_Normoxia"',
#  '"AATGCCGGCTTC_Normoxia"',
#  '"AATGGCAGGTTC_Normoxia"',
#  '"AATGGCAGGTTG_Normoxia"',
#  '"AATGGCAGGTTT_Normoxia"',
#  '"AATGGCCCCACT_Normoxia"',
#  '"AATGGCGAACCG_Normoxia"',
#  '"AATGGGTTCTAG_Normoxia"',
#  '"AATGGTAGTGGC_Normoxia"',
#  '"AATGTATGCAGT_Normoxia"',
#  '"AATGTCAAGACA_Normoxia"',
#  '"AATGTCCAGCGG_Normoxia"',
#  '"AATGTCTATTGC_Normoxia"',
#  '"AATGTCTGTGGC_Normoxia"',
#  '"AATGTTAGGCGA_Normoxia"',
#  '"AATTCATCGAGC_Normoxia"',
#  '"AATTCCTCGTCA_Normoxia"',
#  '"AATTCTCTCCGC_Normoxia"',
#  '"AATTGGTAAGCG_Normoxia"',
#  '"AATTTCCGCCGT_Normoxia"',
#  '"ACAAAAGCGCCG_Normoxia"',
#  '"ACAAACTATCCC_Normoxia"',
#  '"ACAAAGAATGCG_Normoxia"',
#  '"ACAACAGAACTG_Normoxia"',
#  '"ACAACCTCTTGC_Normoxia"',
#  '"ACAACGCGTAGT_Normoxia"',
#  '"ACAACTCCATCT_Normoxia"',
#  '"ACAAGCCCCCAC_Normoxia"',
#  '"ACAAGCGTCATG_Normoxia"',
#  '"ACAAGCTTGAAT_Normoxia"',
#  '"ACAAGTGTGATT_Normoxia"',
#  '"ACAATCAGAGGC_Normoxia"',
#  '"ACAATCGGCCGA_Normoxia"',
#  '"ACAATGGGTCCA_Normoxia"',
#  '"ACACACTGTGCC_Normoxia"',
#  '"ACACAGCCGCCG_Normoxia"',
#  '"ACACAGGGCCAG_Normoxia"',
#  '"ACACATTTTTGG_Normoxia"',
#  '"ACACCAACGGGC_Normoxia"',
#  '"ACACCGATTCCC_Normoxia"',
#  '"ACACCGGCTGCT_Normoxia"',
#  '"ACACCGTACAAA_Normoxia"',
#  '"ACACCTCTATTG_Normoxia"',
#  '"ACACGAATGTAG_Normoxia"',
#  '"ACACGGTCTCCG_Normoxia"',
#  '"ACACTTTGCGAG_Normoxia"',
#  '"ACAGAATCCCGA_Normoxia"',
#  '"ACAGACTCACCG_Normoxia"',
#  '"ACAGAGCCACGG_Normoxia"',
#  '"ACAGCACACCCA_Normoxia"',
#  '"ACAGCATTCCAT_Normoxia"',
#  '"ACAGCCCATTAT_Normoxia"',
#  '"ACAGCGGGAGGT_Normoxia"',
#  '"ACAGCTCAGCAC_Normoxia"',
#  '"ACAGCTCCAGCA_Normoxia"',
#  '"ACAGCTGAGGGA_Normoxia"',
#  '"ACAGTCCCACCC_Normoxia"',
#  '"ACATAAGTAGCG_Normoxia"',
#  '"ACATACGGAGGT_Normoxia"',
#  '"ACATAGAACTCT_Normoxia"',
#  '"ACATAGCCCACA_Normoxia"',
#  '"ACATATTGCCCG_Normoxia"',
#  '"ACATCCAGTTTC_Normoxia"',
#  '"ACATCCGAGCGC_Normoxia"',
#  '"ACATCCTTTCCA_Normoxia"',
#  '"ACATCCTTTCCC_Normoxia"',
#  '"ACATCCTTTCCG_Normoxia"',
#  '"ACATCCTTTCCT_Normoxia"',
#  '"ACATCGCCAGAT_Normoxia"',
#  '"ACATGAAATCCC_Normoxia"',
#  '"ACATGAATGCCG_Normoxia"',
#  '"ACATGGCAGCAA_Normoxia"',
#  '"ACATGGCGGCGC_Normoxia"',
#  '"ACATGTATTGGC_Normoxia"',
#  '"ACATTAAATCGT_Normoxia"',
#  '"ACATTAGCCTAG_Normoxia"',
#  '"ACATTCATGCAC_Normoxia"',
#  '"ACATTCGGCATC_Normoxia"',
#  '"ACATTCTGTCAA_Normoxia"',
#  '"ACATTGCGCCTG_Normoxia"',
#  '"ACATTTCATAAG_Normoxia"',
#  '"ACCAACATGGAA_Normoxia"',
#  '"ACCAACCTGGCG_Normoxia"',
#  '"ACCAACGCGGCA_Normoxia"',
#  '"ACCAAGCACTGC_Normoxia"',
#  '"ACCACATGATTT_Normoxia"',
#  '"ACCACGAAGCCG_Normoxia"',
#  '"ACCACGCAATGC_Normoxia"',
#  '"ACCACGGATCGC_Normoxia"',
#  '"ACCACGGCCACG_Normoxia"',
#  '"ACCACGGCCCTG_Normoxia"',
#  '"ACCACGTAAATG_Normoxia"',
#  '"ACCACTTCGGTC_Normoxia"',
#  '"ACCAGGGTGTAC_Normoxia"',
#  '"ACCAGTCTGGAT_Normoxia"',
#  '"ACCATAACGACC_Normoxia"',
#  '"ACCCACATGCTA_Normoxia"',
#  '"ACCCACCCCTTA_Normoxia"',
#  '"ACCCACTGGTCC_Normoxia"',
#  '"ACCCAGCGCCTC_Normoxia"',
#  '"ACCCATTACAGT_Normoxia"',
#  '"ACCCCACCTGGA_Normoxia"',
#  '"ACCCCCACGATT_Normoxia"',
#  '"ACCCCCCCGGTG_Normoxia"',
#  '"ACCCCCCTCAAA_Normoxia"',
#  '"ACCCCCTGCAAA_Normoxia"',
#  '"ACCCCGATCGAT_Normoxia"',
#  '"ACCCCGGTTTCC_Normoxia"',
#  '"ACCCCTAAAGTT_Normoxia"',
#  '"ACCCCTAGATGC_Normoxia"',
#  '"ACCCCTAGCCAA_Normoxia"',
#  '"ACCCGCAAATTT_Normoxia"',
#  '"ACCCGCAATTTT_Normoxia"',
#  '"ACCCGCATTTCT_Normoxia"',
#  '"ACCCGCCGAACA_Normoxia"',
#  '"ACCCGTCCTCCC_Normoxia"',
#  '"ACCCGTCGTAGT_Normoxia"',
#  '"ACCCTGCCCCGC_Normoxia"',
#  '"ACCCTGCCCGCT_Normoxia"',
#  '"ACCCTGTGACCG_Normoxia"',
#  '"ACCGAACCATGC_Normoxia"',
#  '"ACCGAACCCATG_Normoxia"',
#  '"ACCGAAGCCCAG_Normoxia"',
#  '"ACCGACAGCGTA_Normoxia"',
#  '"ACCGACTTGTGT_Normoxia"',
#  '"ACCGAGGGCCCA_Normoxia"',
#  '"ACCGATACGCTC_Normoxia"',
#  '"ACCGCACTAACG_Normoxia"',
#  '"ACCGCATTTAGC_Normoxia"',
#  '"ACCGCCGATTGC_Normoxia"',
#  '"ACCGCGCGGCCT_Normoxia"',
#  '"ACCGCGGGTATC_Normoxia"',
#  '"ACCGCTACGTCA_Normoxia"',
#  '"ACCGGCCCCCTG_Normoxia"',
#  '"ACCGGCCCTTCC_Normoxia"',
#  '"ACCGGCCCTTCT_Normoxia"',
#  '"ACCGGCCTCTTC_Normoxia"',
#  '"ACCGGCCTTCTT_Normoxia"',
#  '"ACCGGCGACTTT_Normoxia"',
#  '"ACCGTAGAGTTG_Normoxia"',
#  '"ACCGTCCGGTTC_Normoxia"',
#  '"ACCGTCCTATGG_Normoxia"',
#  '"ACCGTCCTATGT_Normoxia"',
#  '"ACCGTCGGGGCA_Normoxia"',
#  '"ACCGTGCTGGGA_Normoxia"',
#  '"ACCGTGTTAAGT_Normoxia"',
#  '"ACCTACACCAAG_Normoxia"',
#  '"ACCTATACCGGA_Normoxia"',
#  '"ACCTATTTTTCG_Normoxia"',
#  '"ACCTCATCCGTC_Normoxia"',
#  '"ACCTCCACACGC_Normoxia"',
#  '"ACCTCCGCCTAG_Normoxia"',
#  '"ACCTCCGCCTGG_Normoxia"',
#  '"ACCTCCGCCTGT_Normoxia"',
#  '"ACCTCCGGCTAG_Normoxia"',
#  '"ACCTCCGGGCCG_Normoxia"',
#  '"ACCTCGACCCGC_Normoxia"',
#  '"ACCTCTGGCCCC_Normoxia"',
#  '"ACCTGATGCAGC_Normoxia"',
#  '"ACCTGCGTACTT_Normoxia"',
#  '"ACCTGCTCCTCT_Normoxia"',
#  '"ACCTGGCCCTGG_Normoxia"',
#  '"ACCTGTCGCGGA_Normoxia"',
#  '"ACCTGTCGCGGC_Normoxia"',
#  '"ACCTGTTCACGG_Normoxia"',
#  '"ACCTTAGACGCT_Normoxia"',
#  '"ACCTTCACACCT_Normoxia"',
#  '"ACCTTCTGTCCG_Normoxia"',
#  '"ACCTTGAGGCGC_Normoxia"',
#  '"ACGAAGCGTACA_Normoxia"',
#  '"ACGAAGTTTCCA_Normoxia"',
#  '"ACGAATGCAACG_Normoxia"',
#  '"ACGACCACGACT_Normoxia"',
#  '"ACGACTACAGAT_Normoxia"',
#  '"ACGAGAAACTAT_Normoxia"',
#  '"ACGAGAAGGGGT_Normoxia"',
#  '"ACGAGAATGCCA_Normoxia"',
#  '"ACGAGGCGCTTC_Normoxia"',
#  '"ACGATAGCGCCC_Normoxia"',
#  '"ACGCAACATAGC_Normoxia"',
#  '"ACGCACAGGGGA_Normoxia"',
#  '"ACGCACGCCGTC_Normoxia"',
#  '"ACGCACGTCCCA_Normoxia"',
#  '"ACGCAGCCTGCA_Normoxia"',
#  '"ACGCCAGCCCCG_Normoxia"',
#  '"ACGCCAGCCGCG_Normoxia"',
#  '"ACGCCCTCACGC_Normoxia"',
#  '"ACGCCTCCGTCT_Normoxia"',
#  '"ACGCCTCGCACC_Normoxia"',
#  '"ACGCCTGGGGGT_Normoxia"',
#  '"ACGCGATGCGCA_Normoxia"',
#  '"ACGCGCCCCAAG_Normoxia"',
#  '"ACGCGGGCGCTC_Normoxia"',
#  '"ACGCGTCGACCT_Normoxia"',
#  '"ACGCGTTTTCTC_Normoxia"',
#  '"ACGCTAAGGCGA_Normoxia"',
#  '"ACGCTCCCGGCT_Normoxia"',
#  '"ACGCTCGCAGTA_Normoxia"',
#  '"ACGCTTGCCACA_Normoxia"',
#  '"ACGCTTGTATCT_Normoxia"',
#  '"ACGGAATATCGG_Normoxia"',
#  '"ACGGACAGCCAC_Normoxia"',
#  '"ACGGATCCCGTC_Normoxia"',
#  '"ACGGCAAGGGAC_Normoxia"',
#  '"ACGGCACAGGCG_Normoxia"',
#  '"ACGGCACATCCT_Normoxia"',
#  '"ACGGCACCGGAG_Normoxia"',
#  '"ACGGCCCCCTGT_Normoxia"',
#  '"ACGGCCCGTCCT_Normoxia"',
#  '"ACGGCCGAAGAA_Normoxia"',
#  '"ACGGCCGTCACC_Normoxia"',
#  '"ACGGCCGTTCAC_Normoxia"',
#  '"ACGGCGACAGTC_Normoxia"',
#  '"ACGGCGGCCGGA_Normoxia"',
#  '"ACGGCTCGCTGG_Normoxia"',
#  '"ACGGCTGCACGA_Normoxia"',
#  '"ACGGGAGTTGAA_Normoxia"',
#  '"ACGGGCCCCTCC_Normoxia"',
#  '"ACGGGCCTTTGA_Normoxia"',
#  '"ACGGGCTCAGCT_Normoxia"',
#  '"ACGGGCTGGTTA_Normoxia"',
#  '"ACGGGCTTCAAT_Normoxia"',
#  '"ACGGGTACCCCG_Normoxia"',
#  '"ACGTACCTGGCC_Normoxia"',
#  '"ACGTACCTTGGC_Normoxia"',
#  '"ACGTAGTCCGCG_Normoxia"',
#  '"ACGTCCTGGCAT_Normoxia"',
#  '"ACGTCGCAGGTT_Normoxia"',
#  '"ACGTCGGCGGGA_Normoxia"',
#  '"ACGTCTGCCGGC_Normoxia"',
#  '"ACGTCTTCGGAG_Normoxia"',
#  '"ACGTGCCGTTCG_Normoxia"',
#  '"ACGTGCCTCCGT_Normoxia"',
#  '"ACGTTAGGACAT_Normoxia"',
#  '"ACGTTCAATCTC_Normoxia"',
#  '"ACGTTCGACAGG_Normoxia"',
#  '"ACGTTGGGACAA_Normoxia"',
#  '"ACGTTTACGTTC_Normoxia"',
#  '"ACTAACCTTATA_Normoxia"',
#  '"ACTAACTCCCAT_Normoxia"',
#  '"ACTAATACAGCA_Normoxia"',
#  '"ACTACACACCAG_Normoxia"',
#  '"ACTACCACAGTG_Normoxia"',
#  '"ACTACGCTGTCA_Normoxia"',
#  '"ACTACGTGACTG_Normoxia"',
#  '"ACTATAAGCTTC_Normoxia"',
#  '"ACTATATCCCGT_Normoxia"',
#  '"ACTATCTTACAC_Normoxia"',
#  '"ACTATTTCAAGG_Normoxia"',
#  '"ACTCACCCAACG_Normoxia"',
#  '"ACTCACTCGGGT_Normoxia"',
#  '"ACTCAGCATCAC_Normoxia"',
#  '"ACTCATCCTGTG_Normoxia"',
#  '"ACTCCCACCTTA_Normoxia"',
#  '"ACTCCCACTTTC_Normoxia"',
#  '"ACTCCCACTTTT_Normoxia"',
#  '"ACTCCCGACGAG_Normoxia"',
#  '"ACTCCGATGTGA_Normoxia"',
#  '"ACTCCGTGGGGC_Normoxia"',
#  '"ACTCCTCCTAGA_Normoxia"',
#  '"ACTCGACGTCTC_Normoxia"',
#  '"ACTCGATGTCGG_Normoxia"',
#  '"ACTCGCCTGTGT_Normoxia"',
#  '"ACTCGGAGACCG_Normoxia"',
#  '"ACTCGTTAAACG_Normoxia"',
#  '"ACTGAGGCTCTG_Normoxia"',
#  '"ACTGAGGCTGGA_Normoxia"',
#  '"ACTGAGGTACGC_Normoxia"',
#  '"ACTGAGTACACG_Normoxia"',
#  '"ACTGATCCTCCA_Normoxia"',
#  '"ACTGATTAGGCT_Normoxia"',
#  '"ACTGCACAGCGA_Normoxia"',
#  '"ACTGCCTAGTCA_Normoxia"',
#  '"ACTGCGACTCGA_Normoxia"',
#  '"ACTGGCGGCGCA_Normoxia"',
#  '"ACTGGGAACCTC_Normoxia"',
#  '"ACTGGTGACATC_Normoxia"',
#  '"ACTGTAACTTGC_Normoxia"',
#  '"ACTGTATTTGGC_Normoxia"',
#  '"ACTGTCAGCACT_Normoxia"',
#  '"ACTTATAGTTCT_Normoxia"',
#  '"ACTTATGGCCGC_Normoxia"',
#  '"ACTTATGGCCGT_Normoxia"',
#  '"ACTTCATTCACT_Normoxia"',
#  '"ACTTCGACGCGC_Normoxia"',
#  '"ACTTCTCCCGCC_Normoxia"',
#  '"ACTTCTCCCGCT_Normoxia"',
#  '"ACTTTCCAGAGC_Normoxia"',
#  '"ACTTTCGCAGCC_Normoxia"',
#  '"ACTTTCGCGCGC_Normoxia"',
#  '"ACTTTCGTCACA_Normoxia"',
#  '"AGAAAACCGTAA_Normoxia"',
#  '"AGAAACCTAGCG_Normoxia"',
#  '"AGAACGCTTTTG_Normoxia"',
#  '"AGAAGATTGTAC_Normoxia"',
#  '"AGAAGCCGCAGT_Normoxia"',
#  '"AGAAGTGCCGAA_Normoxia"',
#  '"AGAAGTGCTACT_Normoxia"',
#  '"AGAATTCTCTCA_Normoxia"',
#  '"AGACAAAATGCA_Normoxia"',
#  '"AGACATGTCTGC_Normoxia"',
#  '"AGACGCATTTTG_Normoxia"',
#  '"AGACGCCCCGTC_Normoxia"',
#  '"AGACGCGGCTGA_Normoxia"',
#  '"AGACGTTTGAGT_Normoxia"',
#  '"AGACTCCCCCTT_Normoxia"',
#  '"AGACTGATGAGG_Normoxia"',
#  '"AGACTTCTATAC_Normoxia"',
#  '"AGAGACCCGTTG_Normoxia"',
#  '"AGAGACGTACAG_Normoxia"',
#  '"AGAGAGGAGACT_Normoxia"',
#  '"AGAGATACAGTA_Normoxia"',
#  '"AGAGCAGTCAGA_Normoxia"',
#  '"AGAGCCCTATTG_Normoxia"',
#  '"AGAGCGCTAGGC_Normoxia"',
#  '"AGAGCGTTTCTT_Normoxia"',
#  '"AGAGGCAAGTGC_Normoxia"',
#  '"AGAGGGAGAACG_Normoxia"',
#  '"AGAGTATAAGAG_Normoxia"',
#  '"AGAGTCCGGACG_Normoxia"',
#  '"AGATACCAAACA_Normoxia"',
#  '"AGATACTCGACA_Normoxia"',
#  '"AGATAGTATGCC_Normoxia"',
#  '"AGATATCTAGCA_Normoxia"',
#  '"AGATCATTATCA_Normoxia"',
#  '"AGATGAAACTCT_Normoxia"',
#  '"AGATGACTTGCA_Normoxia"',
#  '"AGATGCGGCCGT_Normoxia"',
#  '"AGATGTCGTACC_Normoxia"',
#  '"AGATTACGTCGA_Normoxia"',
#  '"AGATTATGTCCA_Normoxia"',
#  '"AGATTTACGCGC_Normoxia"',
#  '"AGCAACATGGAT_Normoxia"',
#  '"AGCAACATTGGA_Normoxia"',
#  '"AGCAAGTTGCCC_Normoxia"',
#  '"AGCAATCCCCTA_Normoxia"',
#  '"AGCAATCCCGTT_Normoxia"',
#  '"AGCACACTCCCA_Normoxia"',
#  '"AGCACACTTCCC_Normoxia"',
#  '"AGCACATACAGC_Normoxia"',
#  '"AGCACCAATCAC_Normoxia"',
#  '"AGCACCTCCCCA_Normoxia"',
#  '"AGCACGTATTTT_Normoxia"',
#  '"AGCACTGTGATG_Normoxia"',
#  '"AGCAGCAACACG_Normoxia"',
#  '"AGCAGCCGAGCA_Normoxia"',
#  '"AGCAGCTCGTGG_Normoxia"',
#  '"AGCAGGAGGTTT_Normoxia"',
#  '"AGCATAGCCTGT_Normoxia"',
#  '"AGCATATACCGC_Normoxia"',
#  '"AGCATGGGTACG_Normoxia"',
#  '"AGCATTCATTCC_Normoxia"',
#  '"AGCCAAAGCGGC_Normoxia"',
#  '"AGCCAACCTGTG_Normoxia"',
#  '"AGCCACATGACG_Normoxia"',
#  '"AGCCACCCTTGC_Normoxia"',
#  '"AGCCAGCTGCCT_Normoxia"',
#  '"AGCCCAGCCGGC_Normoxia"',
#  '"AGCCCCTGTACG_Normoxia"',
#  '"AGCCCCTTCCGT_Normoxia"',
#  '"AGCCCGACCATC_Normoxia"',
#  '"AGCCCGCGGGAA_Normoxia"',
#  '"AGCCCGGCCCAC_Normoxia"',
#  '"AGCCCGGCCCCC_Normoxia"',
#  '"AGCCCGGCCCCT_Normoxia"',
#  '"AGCCCTAGTGCG_Normoxia"',
#  '"AGCCCTTGATCG_Normoxia"',
#  '"AGCCGAACCTAT_Normoxia"',
#  '"AGCCGCACGCAG_Normoxia"',
#  '"AGCCGCGCCAGG_Normoxia"',
#  '"AGCCTAACTTTT_Normoxia"',
#  '"AGCCTCATCAGA_Normoxia"',
#  '"AGCCTCGTCTTC_Normoxia"',
#  '"AGCCTGCCAGGA_Normoxia"',
#  '"AGCCTGGCCTCC_Normoxia"',
#  '"AGCCTTTTGACC_Normoxia"',
#  '"AGCGAACTCGGA_Normoxia"',
#  '"AGCGACGTACTA_Normoxia"',
#  '"AGCGAGGTCCGG_Normoxia"',
#  '"AGCGCACCCCGT_Normoxia"',
#  '"AGCGCCACGAGA_Normoxia"',
#  '"AGCGCGGCGCCG_Normoxia"',
#  '"AGCGCTGCCCCA_Normoxia"',
#  '"AGCGCTTGTAAG_Normoxia"',
#  '"AGCGGCACTAAA_Normoxia"',
#  '"AGCGGCGACCCG_Normoxia"',
#  '"AGCGGCGCATCC_Normoxia"',
#  '"AGCGGCTCGACC_Normoxia"',
#  '"AGCGGGCATACG_Normoxia"',
#  '"AGCGGGCCGTGC_Normoxia"',
#  '"AGCGGGCGGAGA_Normoxia"',
#  '"AGCGTAGGCGCC_Normoxia"',
#  '"AGCGTTGTACTT_Normoxia"',
#  '"AGCTACATTTCA_Normoxia"',
#  '"AGCTATTTCCGA_Normoxia"',
#  '"AGCTCCGACCCG_Normoxia"',
#  '"AGCTCTGTCGGC_Normoxia"',
#  '"AGCTGGGGCTGA_Normoxia"',
#  '"AGCTGTCTGGTG_Normoxia"',
#  '"AGGAACCCTTTT_Normoxia"',
#  '"AGGAAGGCCAGC_Normoxia"',
#  '"AGGACTGCGGGG_Normoxia"',
#  '"AGGACTTGTCAC_Normoxia"',
#  '"AGGAGAGCGGGC_Normoxia"',
#  '"AGGAGCCCCAAC_Normoxia"',
#  '"AGGAGCCCCTTC_Normoxia"',
#  '"AGGATAACAAAG_Normoxia"',
#  '"AGGATACCCTGG_Normoxia"',
#  '"AGGATCATGACA_Normoxia"',
#  '"AGGATTGGGTCC_Normoxia"',
#  '"AGGCACCGTCTC_Normoxia"',
#  '"AGGCAGCGTATT_Normoxia"',
#  '"AGGCAGTCCCTC_Normoxia"',
#  '"AGGCATACGCTA_Normoxia"',
#  '"AGGCATATGCCT_Normoxia"',
#  '"AGGCCAAAGAGC_Normoxia"',
#  '"AGGCCCGACATC_Normoxia"',
#  '"AGGCCCGTTTGC_Normoxia"',
#  '"AGGCCCTGTGAT_Normoxia"',
#  '"AGGCCGTAGTCG_Normoxia"',
#  '"AGGCGCCTAGTG_Normoxia"',
#  '"AGGCTCTTGCGT_Normoxia"',
#  '"AGGCTGCGGGGC_Normoxia"',
#  '"AGGCTGCGGGGG_Normoxia"',
#  '"AGGCTGTTGACG_Normoxia"',
#  '"AGGGAGATCGCC_Normoxia"',
#  '"AGGGATATCATC_Normoxia"',
#  '"AGGGCCCCCCCC_Normoxia"',
#  '"AGGGCGCACTAG_Normoxia"',
#  '"AGGGGCACCCGC_Normoxia"',
#  '"AGGGGCGATGAA_Normoxia"',
#  '"AGGGTCGGAGCG_Normoxia"',
#  '"AGGGTTGCTACG_Normoxia"',
#  '"AGGTAAATCCCT_Normoxia"',
#  '"AGGTACCATAGA_Normoxia"',
#  '"AGGTAGAAAGAG_Normoxia"',
#  '"AGGTAGTTGCTG_Normoxia"',
#  '"AGGTCAGGTTAC_Normoxia"',
#  '"AGGTCCAAGTTG_Normoxia"',
#  '"AGGTCCATAACC_Normoxia"',
#  '"AGGTCCCAAGCT_Normoxia"',
#  '"AGGTCCCATCCC_Normoxia"',
#  '"AGGTCCCTCGCG_Normoxia"',
#  '"AGGTCCGCATCT_Normoxia"',
#  '"AGGTCGCGCACA_Normoxia"',
#  '"AGGTCGTTCATC_Normoxia"',
#  '"AGGTCTCTGTAG_Normoxia"',
#  '"AGGTCTGGTAAA_Normoxia"',
#  '"AGGTCTGGTAAC_Normoxia"',
#  '"AGGTCTGGTAAT_Normoxia"',
#  '"AGGTCTGGTGTC_Normoxia"',
#  '"AGGTGAATTCGA_Normoxia"',
#  '"AGGTGATCTAAG_Normoxia"',
#  '"AGGTGCCCCTAC_Normoxia"',
#  '"AGGTGCGGACTC_Normoxia"',
#  '"AGGTTGCAAAGC_Normoxia"',
#  '"AGGTTGTTATCC_Normoxia"',
#  '"AGTAACCCTAGT_Normoxia"',
#  '"AGTAAGGGTCGC_Normoxia"',
#  '"AGTACGGGGTCA_Normoxia"',
#  '"AGTAGCAGCGGT_Normoxia"',
#  '"AGTAGCCCCTGG_Normoxia"',
#  '"AGTAGGCCCGCA_Normoxia"',
#  '"AGTAGTACCTAG_Normoxia"',
#  '"AGTATCGGAGCA_Normoxia"',
#  '"AGTATGACCCTC_Normoxia"',
#  '"AGTATTTGTTTG_Normoxia"',
#  '"AGTCAATGCTTA_Normoxia"',
#  '"AGTCACGACAAC_Normoxia"',
#  '"AGTCACGCCTGT_Normoxia"',
#  '"AGTCATACCTGC_Normoxia"',
#  '"AGTCCACCCATC_Normoxia"',
#  '"AGTCCAGGTGCG_Normoxia"',
#  '"AGTCCATGATCC_Normoxia"',
#  '"AGTCCCCTCCGA_Normoxia"',
#  '"AGTCCGCGCGTC_Normoxia"',
#  '"AGTCCGCGCGTG_Normoxia"',
#  '"AGTCCGGGGGCG_Normoxia"',
#  '"AGTCCGTAGCAG_Normoxia"',
#  '"AGTCCGTGAAAG_Normoxia"',
#  '"AGTCCGTGAGTT_Normoxia"',
#  '"AGTCCTAAGCCA_Normoxia"',
#  '"AGTCCTTTCAGT_Normoxia"',
#  '"AGTCGAAAGCCC_Normoxia"',
#  '"AGTCGAACGTAC_Normoxia"',
#  '"AGTCTAGGGCTA_Normoxia"',
#  '"AGTCTCGGAAGG_Normoxia"',
#  '"AGTCTCGGATCG_Normoxia"',
#  '"AGTCTGACCCCC_Normoxia"',
#  '"AGTCTGTGAACA_Normoxia"',
#  '"AGTGAACAACGT_Normoxia"',
#  '"AGTGACCAGCCT_Normoxia"',
#  '"AGTGACGTCTAG_Normoxia"',
#  '"AGTGCACCCGAT_Normoxia"',
#  '"AGTGCCCTTCTC_Normoxia"',
#  '"AGTGCCGGCCGC_Normoxia"',
#  '"AGTGCGCTTGGC_Normoxia"',
#  '"AGTGCGGTGTAG_Normoxia"',
#  '"AGTGGACTTGTA_Normoxia"',
#  '"AGTGGCCATAAT_Normoxia"',
#  '"AGTGTAAGGTTT_Normoxia"',
#  '"AGTGTACGCCCT_Normoxia"',
#  '"AGTGTAGCTACC_Normoxia"',
#  '"AGTGTGACTTGT_Normoxia"',
#  '"AGTGTGCACCGC_Normoxia"',
#  '"AGTGTGCCTCGG_Normoxia"',
#  '"AGTGTGCTCGGG_Normoxia"',
#  '"AGTGTGTCGGGC_Normoxia"',
#  '"AGTGTGTCGGGT_Normoxia"',
#  '"AGTGTTGCTTAG_Normoxia"',
#  '"AGTTAACCATAG_Normoxia"',
#  '"AGTTACCAGGCA_Normoxia"',
#  '"AGTTAGATCAGC_Normoxia"',
#  '"AGTTATGTTGTG_Normoxia"',
#  '"AGTTCGCCTTAC_Normoxia"',
#  '"AGTTCTCATATG_Normoxia"',
#  '"AGTTGACTCGTG_Normoxia"',
#  '"AGTTGGAGTAGC_Normoxia"',
#  '"AGTTTTTCCGTT_Normoxia"',
#  '"ATAAATGGGGGT_Normoxia"',
#  '"ATAACACGTGTC_Normoxia"',
#  '"ATAACGTGGGTG_Normoxia"',
#  '"ATAACTTTACGC_Normoxia"',
#  '"ATAAGCCTCGGA_Normoxia"',
#  '"ATACCCCTACTC_Normoxia"',
#  '"ATACCGTGGGGT_Normoxia"',
#  '"ATACGACGGTAC_Normoxia"',
#  '"ATACGGTATGAG_Normoxia"',
#  '"ATACGTCACACG_Normoxia"',
#  '"ATACGTTGGGCA_Normoxia"',
#  '"ATACTCTCAATG_Normoxia"',
#  '"ATAGAACCCCTA_Normoxia"',
#  '"ATAGCCGCCAAA_Normoxia"',
#  '"ATAGCCGCCAGG_Normoxia"',
#  '"ATAGCCGCCAGT_Normoxia"',
#  '"ATAGCCGCCCAA_Normoxia"',
#  '"ATAGCCGGCCAA_Normoxia"',
#  '"ATAGCTATCGCA_Normoxia"',
#  '"ATAGCTTCGCAA_Normoxia"',
#  '"ATAGGAAGGAGC_Normoxia"',
#  '"ATAGGCCGCCAA_Normoxia"',
#  '"ATAGGTACGTGT_Normoxia"',
#  '"ATAGGTATGGTC_Normoxia"',
#  '"ATAGGTTGAGTC_Normoxia"',
#  '"ATAGTCGAAATC_Normoxia"',
#  '"ATAGTCGAAATT_Normoxia"',
#  '"ATAGTTCCTGCA_Normoxia"',
#  '"ATATCACCTCCC_Normoxia"',
#  '"ATATCATCAGGC_Normoxia"',
#  '"ATATCTGTGACT_Normoxia"',
#  '"ATATGTTCCTAC_Normoxia"',
#  '"ATATTTTCGCAC_Normoxia"',
#  '"ATCAACCGTGTG_Normoxia"',
#  '"ATCAACTGTGGG_Normoxia"',
#  '"ATCAGATGCGGG_Normoxia"',
#  '"ATCATTCCCGCC_Normoxia"',
#  '"ATCCACATGAGA_Normoxia"',
#  '"ATCCATTTCGTG_Normoxia"',
#  '"ATCCCAACTTCT_Normoxia"',
#  '"ATCCCAGTAGAG_Normoxia"',
#  '"ATCCCCACATCT_Normoxia"',
#  '"ATCCCCACTTCA_Normoxia"',
#  '"ATCCCCACTTTC_Normoxia"',
#  '"ATCCCCCCTAAA_Normoxia"',
#  '"ATCCCCCTTCTC_Normoxia"',
#  '"ATCCCCCTTCTT_Normoxia"',
#  '"ATCCCGGCCACA_Normoxia"',
#  '"ATCCCTACCAGA_Normoxia"',
#  '"ATCCCTGCCCGC_Normoxia"',
#  '"ATCCCTGCCGCT_Normoxia"',
#  '"ATCCCTTGTCTG_Normoxia"',
#  '"ATCCGACCAAAG_Normoxia"',
#  '"ATCCGCGCGTCC_Normoxia"',
#  '"ATCCGCGCGTCT_Normoxia"',
#  '"ATCCGCGCGTTC_Normoxia"',
#  '"ATCCGGCCTACC_Normoxia"',
#  '"ATCCGGCTGTCC_Normoxia"',
#  '"ATCCTAAAGTCG_Normoxia"',
#  '"ATCCTCTGATAC_Normoxia"',
#  '"ATCCTGACTCGT_Normoxia"',
#  '"ATCCTGCAGGCT_Normoxia"',
#  '"ATCCTGCCTCCT_Normoxia"',
#  '"ATCCTTACAGAC_Normoxia"',
#  '"ATCGCAGTTTCC_Normoxia"',
#  '"ATCGCAGTTTCG_Normoxia"',
#  '"ATCGCCATCCCG_Normoxia"',
#  '"ATCGCCCATCTG_Normoxia"',
#  '"ATCGCCCCAGGA_Normoxia"',
#  '"ATCGCGCCTCAT_Normoxia"',
#  '"ATCGCGCGGTTC_Normoxia"',
#  '"ATCGCGCGTTCA_Normoxia"',
#  '"ATCGCGCTCATT_Normoxia"',
#  '"ATCGCGGGAAGA_Normoxia"',
#  '"ATCGCGGGCTCC_Normoxia"',
#  '"ATCGCTCCCGTC_Normoxia"',
#  '"ATCGCTCTATCA_Normoxia"',
#  '"ATCGCTGCTAGA_Normoxia"',
#  '"ATCGGAGCGCGC_Normoxia"',
#  '"ATCGGCCCCGTA_Normoxia"',
#  '"ATCGGCGGGCTG_Normoxia"',
#  '"ATCGGCGGGCTT_Normoxia"',
#  '"ATCGGGGAGATG_Normoxia"',
#  '"ATCGGGGCGGAC_Normoxia"',
#  '"ATCGTCACGCGT_Normoxia"',
#  '"ATCGTGGTCTCG_Normoxia"',
#  '"ATCGTTCCGCGT_Normoxia"',
#  '"ATCTACCGATTG_Normoxia"',
#  '"ATCTCAGCACCC_Normoxia"',
#  '"ATCTCGTCGGAA_Normoxia"',
#  '"ATCTCTATCATT_Normoxia"',
#  '"ATCTCTGGGTAT_Normoxia"',
#  '"ATCTCTTAGAGT_Normoxia"',
#  '"ATCTGCGTGCGC_Normoxia"',
#  '"ATCTGGATGTTC_Normoxia"',
#  '"ATCTGTGGGTCA_Normoxia"',
#  '"ATCTGTTGTAGG_Normoxia"',
#  '"ATCTTCCGTAAC_Normoxia"',
#  '"ATGAACCGGCTC_Normoxia"',
#  '"ATGAAGGTTAAC_Normoxia"',
#  '"ATGACGAATGGC_Normoxia"',
#  '"ATGAGCCCTGCT_Normoxia"',
#  '"ATGAGCTACATG_Normoxia"',
#  '"ATGAGCTGGCTT_Normoxia"',
#  '"ATGATCGCGTTA_Normoxia"',
#  '"ATGATGCGGTAG_Normoxia"',
#  '"ATGATGGCTGTA_Normoxia"',
#  '"ATGCAGCGAACC_Normoxia"',
#  '"ATGCCATAAACT_Normoxia"',
#  '"ATGCCGCCCCTC_Normoxia"',
#  '"ATGCCTGGCGCG_Normoxia"',
#  '"ATGCGCACTTCC_Normoxia"',
#  '"ATGCGCGCAAAA_Normoxia"',
#  '"ATGCGGTCTCGC_Normoxia"',
#  '"ATGCGTACGGGC_Normoxia"',
#  '"ATGCTAGTGGGC_Normoxia"',
#  '"ATGCTTCTTCCC_Normoxia"',
#  '"ATGCTTCTTCCT_Normoxia"',
#  '"ATGCTTCTTCTC_Normoxia"',
#  '"ATGCTTCTTCTT_Normoxia"',
#  '"ATGGACGCACCA_Normoxia"',
#  '"ATGGACGCACCT_Normoxia"',
#  '"ATGGACGGCACC_Normoxia"',
#  '"ATGGAGCTTCCG_Normoxia"',
#  '"ATGGCACACATT_Normoxia"',
#  '"ATGGCACTTCTG_Normoxia"',
#  '"ATGGCAGGTATC_Normoxia"',
#  '"ATGGCAGGTATT_Normoxia"',
#  '"ATGGCATGCGCA_Normoxia"',
#  '"ATGGCCGCGACG_Normoxia"',
#  '"ATGGCGACGCAT_Normoxia"',
#  '"ATGGCGACGCTC_Normoxia"',
#  '"ATGGCTAGATTC_Normoxia"',
#  '"ATGGCTCATCGT_Normoxia"',
#  '"ATGGCTTCTTCC_Normoxia"',
#  '"ATGGGCGGTGTG_Normoxia"',
#  '"ATGGTAGATTGC_Normoxia"',
#  '"ATGGTTCCGCTC_Normoxia"',
#  '"ATGGTTTCAGAC_Normoxia"',
#  '"ATGTAACAGCGA_Normoxia"',
#  '"ATGTAAGCGTTC_Normoxia"',
#  '"ATGTACCGCGAG_Normoxia"',
#  '"ATGTCAATTCAT_Normoxia"',
#  '"ATGTCCAGGCTA_Normoxia"',
#  '"ATGTCCAGGCTC_Normoxia"',
#  '"ATGTCCAGGCTG_Normoxia"',
#  '"ATGTCGGACGCC_Normoxia"',
#  '"ATGTGCGGAGAT_Normoxia"',
#  '"ATGTGGCATAAG_Normoxia"',
#  '"ATGTTGCACACG_Normoxia"',
#  '"ATGTTGCGCTCC_Normoxia"',
#  '"ATTAATCAACGA_Normoxia"',
#  '"ATTACAGCCGCG_Normoxia"',
#  '"ATTACCTTCCGG_Normoxia"',
#  '"ATTACGTACTCC_Normoxia"',
#  '"ATTACTCCCAGT_Normoxia"',
#  '"ATTACTCCGAAC_Normoxia"',
#  '"ATTATACCAGTA_Normoxia"',
#  '"ATTATAGACCTG_Normoxia"',
#  '"ATTCAATCGTCT_Normoxia"',
#  '"ATTCACTCCAAT_Normoxia"',
#  '"ATTCCCATCTCC_Normoxia"',
#  '"ATTCCGCCAAGT_Normoxia"',
#  '"ATTCGCCGAGCT_Normoxia"',
#  '"ATTCGCCGGCTC_Normoxia"',
#  '"ATTCTCCGCCAC_Normoxia"',
#  '"ATTCTCTTACCG_Normoxia"',
#  '"ATTCTGTAACGA_Normoxia"',
#  '"ATTCTTGGCACC_Normoxia"',
#  '"ATTGGCGATGGT_Normoxia"',
#  '"ATTGGCTCGGCC_Normoxia"',
#  '"ATTGTCCCGAGG_Normoxia"',
#  '"ATTGTCCGAGGA_Normoxia"',
#  '"ATTTCAGCACGG_Normoxia"',
#  '"ATTTTCGGGGGA_Normoxia"',
#  '"CAAAATGTGGGC_Normoxia"',
#  '"CAAACAAGCGCT_Normoxia"',
#  '"CAAACACACACT_Normoxia"',
#  '"CAAACACCCTGG_Normoxia"',
#  '"CAAACGCGCCGT_Normoxia"',
#  '"CAAAGATCAGAG_Normoxia"',
#  '"CAAAGTACGATA_Normoxia"',
#  '"CAAAGTCAAGCT_Normoxia"',
#  '"CAAAGTCCAGCG_Normoxia"',
#  '"CAAATGTATGCC_Normoxia"',
#  '"CAACAAACTCGC_Normoxia"',
#  '"CAACACTAACCT_Normoxia"',
#  '"CAACCATACGAA_Normoxia"',
#  '"CAACCCCCGCAC_Normoxia"',
#  '"CAACCCGAATGA_Normoxia"',
#  '"CAACCCGGCCGA_Normoxia"',
#  '"CAACCCGTCAGG_Normoxia"',
#  '"CAACCGTCGTGC_Normoxia"',
#  '"CAACCTAATAGC_Normoxia"',
#  '"CAACGAGTTTCT_Normoxia"',
#  '"CAACGATAAGAC_Normoxia"',
#  '"CAACGCTCAACG_Normoxia"',
#  '"CAACGCTCCAAC_Normoxia"',
#  '"CAACGGACGGTG_Normoxia"',
#  '"CAACGGAGGCTC_Normoxia"',
#  '"CAACGGCTCAAC_Normoxia"',
#  '"CAACGGTGCACC_Normoxia"',
#  '"CAACGTAATGCT_Normoxia"',
#  '"CAACGTTTTCCG_Normoxia"',
#  '"CAACTACGCGGC_Normoxia"',
#  '"CAACTAGCACTC_Normoxia"',
#  '"CAACTCCGACGA_Normoxia"',
#  '"CAACTGAATGGG_Normoxia"',
#  '"CAACTGCTTCAC_Normoxia"',
#  '"CAACTGGGAACC_Normoxia"',
#  '"CAACTGTCCAGT_Normoxia"',
#  '"CAACTTGTGCTC_Normoxia"',
#  '"CAAGACCGCTGT_Normoxia"',
#  '"CAAGACGCAGTG_Normoxia"',
#  '"CAAGACTTCCGC_Normoxia"',
#  '"CAAGAGACACGC_Normoxia"',
#  '"CAAGAGATGGAT_Normoxia"',
#  '"CAAGCCACCCCT_Normoxia"',
#  '"CAAGCCGGGATG_Normoxia"',
#  '"CAAGCCTCGCTA_Normoxia"',
#  '"CAAGCGCGTCAG_Normoxia"',
#  '"CAAGCGTCATGG_Normoxia"',
#  '"CAAGGAAGTTGC_Normoxia"',
#  '"CAAGGACGAGAC_Normoxia"',
#  '"CAAGGCCACAAG_Normoxia"',
#  '"CAAGGCCGCGGC_Normoxia"',
#  '"CAAGGGCACCAC_Normoxia"',
#  '"CAAGGGTAATTC_Normoxia"',
#  '"CAAGTACGACGA_Normoxia"',
#  '"CAAGTACGGATG_Normoxia"',
#  '"CAAGTAGAGTAT_Normoxia"',
#  '"CAAGTAGGTTTT_Normoxia"',
#  '"CAAGTAGTTTTT_Normoxia"',
#  '"CAAGTGCCCGAA_Normoxia"',
#  '"CAAGTGGGAGCG_Normoxia"',
#  '"CAAGTGTCGCTG_Normoxia"',
#  '"CAAGTGTGATTC_Normoxia"',
#  '"CAAGTGTGATTG_Normoxia"',
#  '"CAAGTGTGATTT_Normoxia"',
#  '"CAATCCACTGGA_Normoxia"',
#  '"CAATCCTAAGAC_Normoxia"',
#  '"CAATCCTCCCTG_Normoxia"',
#  '"CAATCCTCCTTA_Normoxia"',
#  '"CAATCGCACTTC_Normoxia"',
#  '"CAATCGCTCCCA_Normoxia"',
#  '"CAATGGCCTTTG_Normoxia"',
#  '"CAATGGCTAATA_Normoxia"',
#  '"CAATGGGGAAGT_Normoxia"',
#  '"CAATGGGGAGTC_Normoxia"',
#  '"CAATGTATGCCC_Normoxia"',
#  '"CAATGTATGCCT_Normoxia"',
#  '"CAATGTGCCTTC_Normoxia"',
#  '"CAATGTGCTTCG_Normoxia"',
#  '"CAATGTGTCGAG_Normoxia"',
#  '"CAATTAAGCAAC_Normoxia"',
#  '"CAATTACCTCCG_Normoxia"',
#  '"CAATTGAGGAGT_Normoxia"',
#  '"CAATTTAAGAGT_Normoxia"',
#  '"CAATTTTCTTAC_Normoxia"',
#  '"CACAAATCTGTG_Normoxia"',
#  '"CACAACCCTGCA_Normoxia"',
#  '"CACAACCTGTGA_Normoxia"',
#  '"CACAACGAACTC_Normoxia"',
#  '"CACAACGAGTGG_Normoxia"',
#  '"CACAACTGCCCT_Normoxia"',
#  '"CACAAGGGCCTG_Normoxia"',
#  '"CACAAGGTCGCT_Normoxia"',
#  '"CACAATTACTAT_Normoxia"',
#  '"CACACCCCCTTC_Normoxia"',
#  '"CACACCTCTCTG_Normoxia"',
#  '"CACACTGTCGAC_Normoxia"',
#  '"CACAGAACCTCA_Normoxia"',
#  '"CACAGCAAGTTG_Normoxia"',
#  '"CACAGCACGTAA_Normoxia"',
#  '"CACAGCACTTCG_Normoxia"',
#  '"CACAGCCTCAGT_Normoxia"',
#  '"CACAGCTGCCCT_Normoxia"',
#  '"CACAGCTGCCTT_Normoxia"',
#  '"CACAGCTGCGGT_Normoxia"',
#  '"CACAGGCGTTCC_Normoxia"',
#  '"CACAGGTCGTGT_Normoxia"',
#  '"CACAGTAGACTC_Normoxia"',
#  '"CACAGTGTGGAC_Normoxia"',
#  ...]

# %%
np.shape(df)
# Out:
# (3000, 14682)

# %%
df.head(5)
# Out:
#            "AAAAAACCCGGC_Normoxia"  "AAAACCGGATGC_Normoxia"  \
# "H1-5"                           2                        2
# "MALAT1"                         3                        3
# "MT-RNR2"                        0                        0
# "ARVCF"                          0                        0
# "BCYRN1"                         0                        1
#
#            "AAAACGAGCTAG_Normoxia"  "AAAACTTCCCCG_Normoxia"  \
# "H1-5"                           5                        1
# "MALAT1"                         2                        3
# "MT-RNR2"                        0                        0
# "ARVCF"                          0                        0
# "BCYRN1"                         1                        0
#
#            "AAAAGCCTACCC_Normoxia"  "AAACACAAATCT_Normoxia"  \
# "H1-5"                           0                        0
# "MALAT1"                        12                        3
# "MT-RNR2"                        0                        0
# "ARVCF"                          0                        0
# "BCYRN1"                         0                        1
#
#            "AAACCAAGCCCA_Normoxia"  "AAACCATGCACT_Normoxia"  \
# "H1-5"                           0                        0
# "MALAT1"                         1                        2
# "MT-RNR2"                        0                        0
# "ARVCF"                          0                        0
# "BCYRN1"                         1                        2
#
#            "AAACCTCCGGCT_Normoxia"  "AAACGCCGGTCC_Normoxia"  ...  \
# "H1-5"                           1                        0  ...
# "MALAT1"                         0                        0  ...
# "MT-RNR2"                        0                        1  ...
# "ARVCF"                          0                        0  ...
# "BCYRN1"                         0                        3  ...
#
#            "TTTTCTGATGGT_Hypoxia"  "TTTTGATTCAGA_Hypoxia"  \
# "H1-5"                          0                       1
# "MALAT1"                        3                       1
# "MT-RNR2"                       1                       2
# "ARVCF"                         0                       0
# "BCYRN1"                        1                       1
#
#            "TTTTGCAACTGA_Hypoxia"  "TTTTGCCGGGCC_Hypoxia"  \
# "H1-5"                          0                       2
# "MALAT1"                        1                       1
# "MT-RNR2"                       2                       2
# "ARVCF"                         0                       0
# "BCYRN1"                        0                       1
#
#            "TTTTGTTAGCCT_Hypoxia"  "TTTTTACCAATC_Hypoxia"  \
# "H1-5"                          1                       0
# "MALAT1"                        4                       0
# "MT-RNR2"                       0                       0
# "ARVCF"                         0                       0
# "BCYRN1"                        1                       0
#
#            "TTTTTCCGTGCA_Hypoxia"  "TTTTTGCCTGGG_Hypoxia"  \
# "H1-5"                          0                       0
# "MALAT1"                        4                       1
# "MT-RNR2"                       1                       0
# "ARVCF"                         0                       0
# "BCYRN1"                        0                       1
#
#            "TTTTTGTAACAG_Hypoxia"  "TTTTTTTGAATC_Hypoxia"
# "H1-5"                          3                       1
# "MALAT1"                        3                       6
# "MT-RNR2"                       1                       0
# "ARVCF"                         0                       0
# "BCYRN1"                        0                       0
#
# [5 rows x 14682 columns]

# %%
df.dtypes
# Out:
# "AAAAAACCCGGC_Normoxia"    int64
# "AAAACCGGATGC_Normoxia"    int64
# "AAAACGAGCTAG_Normoxia"    int64
# "AAAACTTCCCCG_Normoxia"    int64
# "AAAAGCCTACCC_Normoxia"    int64
#                            ...
# "TTTTTACCAATC_Hypoxia"     int64
# "TTTTTCCGTGCA_Hypoxia"     int64
# "TTTTTGCCTGGG_Hypoxia"     int64
# "TTTTTGTAACAG_Hypoxia"     int64
# "TTTTTTTGAATC_Hypoxia"     int64
# Length: 14682, dtype: object

# %%
X= df.to_numpy()
X
np.shape(X)
# Out:
# (3000, 14682)

# %%
print(df.isnull().sum())
# Out:
# "AAAAAACCCGGC_Normoxia"    0
# "AAAACCGGATGC_Normoxia"    0
# "AAAACGAGCTAG_Normoxia"    0
# "AAAACTTCCCCG_Normoxia"    0
# "AAAAGCCTACCC_Normoxia"    0
#                           ..
# "TTTTTACCAATC_Hypoxia"     0
# "TTTTTCCGTGCA_Hypoxia"     0
# "TTTTTGCCTGGG_Hypoxia"     0
# "TTTTTGTAACAG_Hypoxia"     0
# "TTTTTTTGAATC_Hypoxia"     0
# Length: 14682, dtype: int64

# %%
df = df.dropna()  # Dropping the missing values.
df.count()
# Out:
# "AAAAAACCCGGC_Normoxia"    3000
# "AAAACCGGATGC_Normoxia"    3000
# "AAAACGAGCTAG_Normoxia"    3000
# "AAAACTTCCCCG_Normoxia"    3000
# "AAAAGCCTACCC_Normoxia"    3000
#                            ...
# "TTTTTACCAATC_Hypoxia"     3000
# "TTTTTCCGTGCA_Hypoxia"     3000
# "TTTTTGCCTGGG_Hypoxia"     3000
# "TTTTTGTAACAG_Hypoxia"     3000
# "TTTTTTTGAATC_Hypoxia"     3000
# Length: 14682, dtype: int64

# %%
print(df.isnull().sum())   # After dropping the values
# Out:
# "AAAAAACCCGGC_Normoxia"    0
# "AAAACCGGATGC_Normoxia"    0
# "AAAACGAGCTAG_Normoxia"    0
# "AAAACTTCCCCG_Normoxia"    0
# "AAAAGCCTACCC_Normoxia"    0
#                           ..
# "TTTTTACCAATC_Hypoxia"     0
# "TTTTTCCGTGCA_Hypoxia"     0
# "TTTTTGCCTGGG_Hypoxia"     0
# "TTTTTGTAACAG_Hypoxia"     0
# "TTTTTTTGAATC_Hypoxia"     0
# Length: 14682, dtype: int64

# %%
df.iloc[ 1:5 , 1:5 ]
# Out:
#            "AAAACCGGATGC_Normoxia"  "AAAACGAGCTAG_Normoxia"  \
# "MALAT1"                         3                        2
# "MT-RNR2"                        0                        0
# "ARVCF"                          0                        0
# "BCYRN1"                         1                        1
#
#            "AAAACTTCCCCG_Normoxia"  "AAAAGCCTACCC_Normoxia"
# "MALAT1"                         3                       12
# "MT-RNR2"                        0                        0
# "ARVCF"                          0                        0
# "BCYRN1"                         0                        0

# %%
df.describe()
# Out:
#        "AAAAAACCCGGC_Normoxia"  "AAAACCGGATGC_Normoxia"  \
# count               3000.00000              3000.000000
# mean                   0.02900                 0.041667
# std                    0.23276                 0.309778
# min                    0.00000                 0.000000
# 25%                    0.00000                 0.000000
# 50%                    0.00000                 0.000000
# 75%                    0.00000                 0.000000
# max                    5.00000                 9.000000
#
#        "AAAACGAGCTAG_Normoxia"  "AAAACTTCCCCG_Normoxia"  \
# count              3000.000000              3000.000000
# mean                  0.024333                 0.021667
# std                   0.231860                 0.189409
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                   7.000000                 4.000000
#
#        "AAAAGCCTACCC_Normoxia"  "AAACACAAATCT_Normoxia"  \
# count              3000.000000              3000.000000
# mean                  0.029667                 0.020000
# std                   0.323761                 0.170126
# min                   0.000000                 0.000000
# 25%                   0.000000                 0.000000
# 50%                   0.000000                 0.000000
# 75%                   0.000000                 0.000000
# max                  12.000000                 3.000000
#
#        "AAACCAAGCCCA_Normoxia"  "AAACCATGCACT_Normoxia"  \
# count              3000.000000               3000.00000
# mean                  0.036000                  0.02600
# std                   0.250449                  0.23525
# min                   0.000000                  0.00000
# 25%                   0.000000                  0.00000
# 50%                   0.000000                  0.00000
# 75%                   0.000000                  0.00000
# max                   4.000000                  6.00000
#
#        "AAACCTCCGGCT_Normoxia"  "AAACGCCGGTCC_Normoxia"  ...  \
# count              3000.000000              3000.000000  ...
# mean                  0.034000                 0.029333  ...
# std                   0.231362                 0.218683  ...
# min                   0.000000                 0.000000  ...
# 25%                   0.000000                 0.000000  ...
# 50%                   0.000000                 0.000000  ...
# 75%                   0.000000                 0.000000  ...
# max                   4.000000                 4.000000  ...
#
#        "TTTTCTGATGGT_Hypoxia"  "TTTTGATTCAGA_Hypoxia"  "TTTTGCAACTGA_Hypoxia"  \
# count             3000.000000             3000.000000             3000.000000
# mean                 0.043000                0.049667                0.037000
# std                  0.271739                0.319219                0.279864
# min                  0.000000                0.000000                0.000000
# 25%                  0.000000                0.000000                0.000000
# 50%                  0.000000                0.000000                0.000000
# 75%                  0.000000                0.000000                0.000000
# max                  4.000000                7.000000                7.000000
#
#        "TTTTGCCGGGCC_Hypoxia"  "TTTTGTTAGCCT_Hypoxia"  "TTTTTACCAATC_Hypoxia"  \
# count             3000.000000             3000.000000             3000.000000
# mean                 0.047667                0.057000                0.023333
# std                  0.259648                0.304053                0.214797
# min                  0.000000                0.000000                0.000000
# 25%                  0.000000                0.000000                0.000000
# 50%                  0.000000                0.000000                0.000000
# 75%                  0.000000                0.000000                0.000000
# max                  4.000000                5.000000                4.000000
#
#        "TTTTTCCGTGCA_Hypoxia"  "TTTTTGCCTGGG_Hypoxia"  "TTTTTGTAACAG_Hypoxia"  \
# count             3000.000000             3000.000000             3000.000000
# mean                 0.041667                0.041667                0.043333
# std                  0.236536                0.285116                0.267356
# min                  0.000000                0.000000                0.000000
# 25%                  0.000000                0.000000                0.000000
# 50%                  0.000000                0.000000                0.000000
# 75%                  0.000000                0.000000                0.000000
# max                  4.000000                5.000000                5.000000
#
#        "TTTTTTTGAATC_Hypoxia"
# count             3000.000000
# mean                 0.040000
# std                  0.282418
# min                  0.000000
# 25%                  0.000000
# 50%                  0.000000
# 75%                  0.000000
# max                  6.000000
#
# [8 rows x 14682 columns]

# %%
cnames = list(df.columns)
cnames[1]
sns.boxplot(x=df[cnames[1]])
# Out:
# <Axes: xlabel='"AAAACCGGATGC_Normoxia"'>

# %%
sns.violinplot(x=df[cnames[1]])
# Out:
# <Axes: xlabel='"AAAACCGGATGC_Normoxia"'>

# %%
df_small = df.iloc[:, :50]
np.shape(df_small)
plt.figure(figsize=(16, 4))
plot = sns.violinplot(data=df_small, palette="Set3", cut=0)
plt.setp(plot.get_xticklabels(), rotation=90)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
print(IQR)
# Out:
# "AAAAAACCCGGC_Normoxia"    0.0
# "AAAACCGGATGC_Normoxia"    0.0
# "AAAACGAGCTAG_Normoxia"    0.0
# "AAAACTTCCCCG_Normoxia"    0.0
# "AAAAGCCTACCC_Normoxia"    0.0
#                           ...
# "TTTTTACCAATC_Hypoxia"     0.0
# "TTTTTCCGTGCA_Hypoxia"     0.0
# "TTTTTGCCTGGG_Hypoxia"     0.0
# "TTTTTGTAACAG_Hypoxia"     0.0
# "TTTTTTTGAATC_Hypoxia"     0.0
# Length: 14682, dtype: float64

# %%
df_noOut = df[~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]
df_noOut.shape
df_noOut.head(3)
# Out:
# Empty DataFrame
# Columns: ["AAAAAACCCGGC_Normoxia", "AAAACCGGATGC_Normoxia", "AAAACGAGCTAG_Normoxia", "AAAACTTCCCCG_Normoxia", "AAAAGCCTACCC_Normoxia", "AAACACAAATCT_Normoxia", "AAACCAAGCCCA_Normoxia", "AAACCATGCACT_Normoxia", "AAACCTCCGGCT_Normoxia", "AAACGCCGGTCC_Normoxia", "AAACGCCGTTCC_Normoxia", "AAACGGACGCTC_Normoxia", "AAACGTAGAGCG_Normoxia", "AAACGTTCACTG_Normoxia", "AAACTCATAAAT_Normoxia", "AAAGACGGTACC_Normoxia", "AAAGAGTGTACG_Normoxia", "AAAGCTGACGAA_Normoxia", "AAAGGCGGCAGG_Normoxia", "AAAGGCGTTCGA_Normoxia", "AAAGTCTGGGTC_Normoxia", "AAAGTGGCACCC_Normoxia", "AAAGTGGTTCGT_Normoxia", "AAAGTGTTGTTC_Normoxia", "AAATAGCCAGTT_Normoxia", "AAATCCCATATA_Normoxia", "AAATCGTGGTTG_Normoxia", "AAATCTGGCGAC_Normoxia", "AAATGACAGTCC_Normoxia", "AAATGCAAAGGC_Normoxia", "AAATGCCGGCTT_Normoxia", "AAATGTTACGAG_Normoxia", "AAATTTTACCCG_Normoxia", "AAATTTTTAACT_Normoxia", "AACAATTGAAGA_Normoxia", "AACACACGCCCG_Normoxia", "AACACCCCCCTC_Normoxia", "AACACCCTCCGA_Normoxia", "AACACCGGCTGC_Normoxia", "AACACTAGCCGG_Normoxia", "AACACTAGGATC_Normoxia", "AACAGAGCAGCC_Normoxia", "AACAGATAGAAG_Normoxia", "AACATAATCAGT_Normoxia", "AACATACAATGG_Normoxia", "AACATATGGACT_Normoxia", "AACCAAGGCTCC_Normoxia", "AACCACCTGGTG_Normoxia", "AACCAGGGTTGT_Normoxia", "AACCAGTCCAAC_Normoxia", "AACCCACAACCT_Normoxia", "AACCCGCAATTT_Normoxia", "AACCCGCCATTA_Normoxia", "AACCCGGAGCGC_Normoxia", "AACCCGTACATC_Normoxia", "AACCCGTTCGCG_Normoxia", "AACCCTCCCGAT_Normoxia", "AACCCTGCCGTG_Normoxia", "AACCGAGGCCAC_Normoxia", "AACCGATGAGTT_Normoxia", "AACCGCGAGCCC_Normoxia", "AACCGCGAGCCT_Normoxia", "AACCGCGAGCTC_Normoxia", "AACCGTCTCTTA_Normoxia", "AACCTAATACTT_Normoxia", "AACCTACGAGAG_Normoxia", "AACCTACTAGCG_Normoxia", "AACCTCACCGCT_Normoxia", "AACCTCCCGAGT_Normoxia", "AACCTCCGGCTC_Normoxia", "AACCTCCGGCTT_Normoxia", "AACCTGCTTACG_Normoxia", "AACCTGGGTGTT_Normoxia", "AACGACCACCGG_Normoxia", "AACGACCGCGGG_Normoxia", "AACGACTACCCT_Normoxia", "AACGCAGTTTAT_Normoxia", "AACGCCCGCGGG_Normoxia", "AACGCCGCCAGT_Normoxia", "AACGCCGCGGGC_Normoxia", "AACGCCGCGGGT_Normoxia", "AACGCCTGTCAC_Normoxia", "AACGCGTGCTAT_Normoxia", "AACGCTCCGGAA_Normoxia", "AACGGACCCCTG_Normoxia", "AACGGACGGGAT_Normoxia", "AACGGAGCATTT_Normoxia", "AACGGCACCCTG_Normoxia", "AACGGCCACCTG_Normoxia", "AACGGCCCCAAC_Normoxia", "AACGGCCCCAAT_Normoxia", "AACGGCCCCATG_Normoxia", "AACGGCCCCCAC_Normoxia", "AACGGCCCCCCC_Normoxia", "AACGGCCCCCCT_Normoxia", "AACGGCCCCCGC_Normoxia", "AACGGCCCCCGG_Normoxia", "AACGGCCCCCGT_Normoxia", "AACGGCCCCCTA_Normoxia", "AACGGCCCCCTT_Normoxia", ...]
# Index: []
#
# [0 rows x 14682 columns]

# %%
sns.boxplot(x=df_noOut[cnames[1]])
# Out:
# <Axes: >

# %%
df_noOut_small = df.iloc[:, :50]
np.shape(df_noOut_small)
plt.figure(figsize=(16,4))
plot=sns.violinplot(data=df_noOut_small,palette="Set3",cut=0)
plt.setp(plot.get_xticklabels(), rotation=90)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
from scipy.stats import kurtosis, skew

colN = np.shape(df)[1]
colN
df_skew_cells = []
for i in range(colN):
    v_df = df[cnames[i]]
    df_skew_cells += [skew(v_df)]
#  df_skew_cells += [df[cnames[i]].skew()]
df_skew_cells
sns.histplot(df_skew_cells, bins=100)
plt.xlabel('Skewness of single cells expression profiles - original df')
# Out:
# Text(0.5, 0, 'Skewness of single cells expression profiles - original df')

# %%
df_kurt_cells = []
for i in range(colN):
    v_df = df[cnames[i]]
    df_kurt_cells += [kurtosis(v_df)]
#   df_kurt_cells += [df[cnames[i]].kurt()]
df_kurt_cells
sns.histplot(df_kurt_cells, bins=100)
plt.xlabel('Kurtosis of single cells expression profiles - original df')
# Out:
# Text(0.5, 0, 'Kurtosis of single cells expression profiles - original df')

# %%
xnorm = np.random.normal(0, 2, 10000000)   # create random values based on a normal distribution
xnorm

print( "Excess kurtosis of normal distribution: ",  kurtosis(xnorm) )
print( "Skewness of normal distribution: ", skew(xnorm) )
# Out:
# Excess kurtosis of normal distribution:  -0.00023682230205546162
# Skewness of normal distribution:  -0.0002883789514074507

# %%
df11_log2 = np.log2(df[cnames[1]] + 1)
sns.boxplot(x=df11_log2)
# Out:
# <Axes: xlabel='"AAAACCGGATGC_Normoxia"'>

# %%
sns.violinplot(x=df11_log2)
# Out:
# <Axes: xlabel='"AAAACCGGATGC_Normoxia"'>

# %%
display(df11_log2.describe().round(2))
# Out:
# count    3000.00
# mean        0.04
# std         0.21
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%         0.00
# max         3.32
# Name: "AAAACCGGATGC_Normoxia", dtype: float64

# %%
df1 = df + 1
df1_log2 = df1.apply(np.log2)
# I'm selecting part of the data as the plots would otherwise take too long to generate
df1_log2_small = df1_log2.iloc[:, :50]
np.shape(df1_log2_small)
plt.figure(figsize=(16,4))
plot=sns.violinplot(data=df1_log2_small,palette="Set3",cut=0)
plt.setp(plot.get_xticklabels(), rotation=90)
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
df1_log2_skew_cells = []
for i in range(colN):
    v_df = df1_log2[cnames[i]]
    df1_log2_skew_cells += [skew(v_df)]
df1_log2_skew_cells
sns.histplot(df1_log2_skew_cells, bins=100)
plt.xlabel('Skewness of single cells expression profiles - log2 df')
# Out:
# Text(0.5, 0, 'Skewness of single cells expression profiles - log2 df')

# %%
df1_log2_kurt_cells = []
for i in range(colN) :
     v_df = df1_log2[cnames[i]]
     df1_log2_kurt_cells += [kurtosis(v_df)]
sns.histplot(df1_log2_kurt_cells,bins=100)
plt.xlabel('Kurtosis of single cells expression profiles - log2 df')
# Out:
# Text(0.5, 0, 'Kurtosis of single cells expression profiles - log2 df')

# %%
df = df1_log2
df_small = df.iloc[:, 10:30]  #just selecting part of the samples so run time not too long
sns.displot(data=df_small, palette="Set3", kind="kde", bw_adjust=2)

# %%
duplicate_rows_df = df[df.duplicated(keep=False)]
print("number of duplicate rows: ", duplicate_rows_df.shape)
print("number of duplicate rows: ", duplicate_rows_df)
# Out:
# number of duplicate rows:  (0, 14682)
# number of duplicate rows:  Empty DataFrame
# Columns: ["AAAAAACCCGGC_Normoxia", "AAAACCGGATGC_Normoxia", "AAAACGAGCTAG_Normoxia", "AAAACTTCCCCG_Normoxia", "AAAAGCCTACCC_Normoxia", "AAACACAAATCT_Normoxia", "AAACCAAGCCCA_Normoxia", "AAACCATGCACT_Normoxia", "AAACCTCCGGCT_Normoxia", "AAACGCCGGTCC_Normoxia", "AAACGCCGTTCC_Normoxia", "AAACGGACGCTC_Normoxia", "AAACGTAGAGCG_Normoxia", "AAACGTTCACTG_Normoxia", "AAACTCATAAAT_Normoxia", "AAAGACGGTACC_Normoxia", "AAAGAGTGTACG_Normoxia", "AAAGCTGACGAA_Normoxia", "AAAGGCGGCAGG_Normoxia", "AAAGGCGTTCGA_Normoxia", "AAAGTCTGGGTC_Normoxia", "AAAGTGGCACCC_Normoxia", "AAAGTGGTTCGT_Normoxia", "AAAGTGTTGTTC_Normoxia", "AAATAGCCAGTT_Normoxia", "AAATCCCATATA_Normoxia", "AAATCGTGGTTG_Normoxia", "AAATCTGGCGAC_Normoxia", "AAATGACAGTCC_Normoxia", "AAATGCAAAGGC_Normoxia", "AAATGCCGGCTT_Normoxia", "AAATGTTACGAG_Normoxia", "AAATTTTACCCG_Normoxia", "AAATTTTTAACT_Normoxia", "AACAATTGAAGA_Normoxia", "AACACACGCCCG_Normoxia", "AACACCCCCCTC_Normoxia", "AACACCCTCCGA_Normoxia", "AACACCGGCTGC_Normoxia", "AACACTAGCCGG_Normoxia", "AACACTAGGATC_Normoxia", "AACAGAGCAGCC_Normoxia", "AACAGATAGAAG_Normoxia", "AACATAATCAGT_Normoxia", "AACATACAATGG_Normoxia", "AACATATGGACT_Normoxia", "AACCAAGGCTCC_Normoxia", "AACCACCTGGTG_Normoxia", "AACCAGGGTTGT_Normoxia", "AACCAGTCCAAC_Normoxia", "AACCCACAACCT_Normoxia", "AACCCGCAATTT_Normoxia", "AACCCGCCATTA_Normoxia", "AACCCGGAGCGC_Normoxia", "AACCCGTACATC_Normoxia", "AACCCGTTCGCG_Normoxia", "AACCCTCCCGAT_Normoxia", "AACCCTGCCGTG_Normoxia", "AACCGAGGCCAC_Normoxia", "AACCGATGAGTT_Normoxia", "AACCGCGAGCCC_Normoxia", "AACCGCGAGCCT_Normoxia", "AACCGCGAGCTC_Normoxia", "AACCGTCTCTTA_Normoxia", "AACCTAATACTT_Normoxia", "AACCTACGAGAG_Normoxia", "AACCTACTAGCG_Normoxia", "AACCTCACCGCT_Normoxia", "AACCTCCCGAGT_Normoxia", "AACCTCCGGCTC_Normoxia", "AACCTCCGGCTT_Normoxia", "AACCTGCTTACG_Normoxia", "AACCTGGGTGTT_Normoxia", "AACGACCACCGG_Normoxia", "AACGACCGCGGG_Normoxia", "AACGACTACCCT_Normoxia", "AACGCAGTTTAT_Normoxia", "AACGCCCGCGGG_Normoxia", "AACGCCGCCAGT_Normoxia", "AACGCCGCGGGC_Normoxia", "AACGCCGCGGGT_Normoxia", "AACGCCTGTCAC_Normoxia", "AACGCGTGCTAT_Normoxia", "AACGCTCCGGAA_Normoxia", "AACGGACCCCTG_Normoxia", "AACGGACGGGAT_Normoxia", "AACGGAGCATTT_Normoxia", "AACGGCACCCTG_Normoxia", "AACGGCCACCTG_Normoxia", "AACGGCCCCAAC_Normoxia", "AACGGCCCCAAT_Normoxia", "AACGGCCCCATG_Normoxia", "AACGGCCCCCAC_Normoxia", "AACGGCCCCCCC_Normoxia", "AACGGCCCCCCT_Normoxia", "AACGGCCCCCGC_Normoxia", "AACGGCCCCCGG_Normoxia", "AACGGCCCCCGT_Normoxia", "AACGGCCCCCTA_Normoxia", "AACGGCCCCCTT_Normoxia", ...]
# Index: []
#
# [0 rows x 14682 columns]

# %%
duplicate_rows_df_t = duplicate_rows_df.T
duplicate_rows_df_t
c_dupl = duplicate_rows_df_t.corr()
c_dupl
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
duplicate_rows_df_t.describe()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 duplicate_rows_df_t.describe()
#
# File ~\PycharmProjects\AI-Lab\venv\lib\site-packages\pandas\core\generic.py:11976, in NDFrame.describe(self, percentiles, include, exclude)
#   11734 @final
#   11735 def describe(
#   11736     self,
#    (...)
#   11739     exclude=None,
#   11740 ) -> Self:
#   11741     """
#   11742     Generate descriptive statistics.
#   11743
#    (...)
#   11974     max            NaN      3.0
#   11975     """
# > 11976     return describe_ndframe(
#   11977         obj=self,
#   11978         include=include,
#   11979         exclude=exclude,
#   11980         percentiles=percentiles,
#   11981     ).__finalize__(self, method="describe")
#
# File ~\PycharmProjects\AI-Lab\venv\lib\site-packages\pandas\core\methods\describe.py:91, in describe_ndframe(obj, include, exclude, percentiles)
#      87     describer = SeriesDescriber(
#      88         obj=cast("Series", obj),
#      89     )
#      90 else:
# ---> 91     describer = DataFrameDescriber(
#      92         obj=cast("DataFrame", obj),
#      93         include=include,
#      94         exclude=exclude,
#      95     )
#      97 result = describer.describe(percentiles=percentiles)
#      98 return cast(NDFrameT, result)
#
# File ~\PycharmProjects\AI-Lab\venv\lib\site-packages\pandas\core\methods\describe.py:162, in DataFrameDescriber.__init__(self, obj, include, exclude)
#     159 self.exclude = exclude
#     161 if obj.ndim == 2 and obj.columns.size == 0:
# --> 162     raise ValueError("Cannot describe a DataFrame without columns")
#     164 super().__init__(obj)
#
# ValueError: Cannot describe a DataFrame without columns

# %%
df_noDup = df.drop_duplicates()
df_noDup.count()

# %%
df = df_noDup

# %%
plt.figure(figsize=(10, 5))
#df_small = df.iloc[:, :50]
#c= df_small.corr()
c = df.corr()
midpoint = (c.values.max() - c.values.min()) / 2 + c.values.min()
#sns.heatmap(c,cmap='coolwarm',annot=True, center=midpoint )
sns.heatmap(c, cmap='coolwarm', center=0)
print("Number of cells included: ", np.shape(c))
print("Average correlation of expression profiles between cells: ", midpoint)
print("Min. correlation of expression profiles between cells: ", c.values.min())

# %%
np.shape(c)
type(c)
c.head(3)
c_small=c.iloc[:,:3]
sns.histplot(c_small,bins=100)
plt.ylabel('Frequency')
plt.xlabel('Correlation between cells expression profiles')
